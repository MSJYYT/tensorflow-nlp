# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow1/free_chat/chinese_lccc/main')

# %%
# %tensorflow_version 1.x
# !pip install texar

# %%
import tensorflow as tf
import texar.tf as tx

import numpy as np
import pprint
import logging
import copy

from pathlib import Path
from texar.tf.modules import TransformerEncoder

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 1.15.2
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  char2idx = params['char2idx']
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      line = line.rstrip()
      source, target = line.split('<SEP>')
      source = [char2idx.get(c, len(char2idx)) for c in list(source)]
      target = [char2idx.get(c, len(char2idx)) for c in list(target)]
      if len(source) > params['max_len']:
        source = source[:params['max_len']]
      if len(target) > params['max_len']:
        target = target[:params['max_len']]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, (target_in, target_out))

# %%
def dataset(is_training, params):
  _shapes = ([None], ([None], [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (0, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    pprint.pprint(variables)
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    def cell_fn():
        cell = tf.nn.rnn_cell.LSTMCell(params['rnn_units'],
                                       initializer=tf.orthogonal_initializer())
        return cell
    if params['dec_layers'] > 1:
      cells = []
      for i in range(params['dec_layers']):
        if i == params['dec_layers'] - 1:
          cells.append(cell_fn())
        else:
          cells.append(tf.nn.rnn_cell.ResidualWrapper(cell_fn(), residual_fn=lambda i,o: tf.concat((i,o), -1)))
      return tf.nn.rnn_cell.MultiRNNCell(cells)
    else:
      return cell_fn()

  
def dec_cell(enc_out, enc_seq_len):
    attn = tf.contrib.seq2seq.BahdanauAttention(
        num_units = params['rnn_units'],
        memory = enc_out,
        memory_sequence_length = enc_seq_len)
    
    return tf.contrib.seq2seq.AttentionWrapper(
        cell = rnn_cell(),
        attention_mechanism = attn,
        attention_layer_size = params['rnn_units'])

# %%
class TiedDense(tf.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    if params['rnn_units'] != 300:
      self.proj_W = self.add_weight(name='proj_W',
                                    shape=[params['rnn_units'], params['embed_dim']],
                                    trainable=True)
      self.proj_b = self.add_weight(name='proj_b',
                                    shape=[params['embed_dim']],
                                    trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    if params['rnn_units'] != 300:
      inputs = params['activation'](tf.nn.bias_add(tf.matmul(inputs, self.proj_W), self.proj_b))
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
def forward(words, labels, mode):
    words_len = tf.count_nonzero(words, 1, dtype=tf.int32)
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    batch_sz = tf.shape(words)[0]
    
  
    with tf.variable_scope('Embedding'):
        embedding = tf.Variable(np.load('../vocab/char.npy'),
                                dtype=tf.float32,
                                name='fasttext_vectors')
        embedding = tf.concat([tf.zeros(shape=[1, params['embed_dim']]), embedding[1:, :]], axis=0)
        x = tf.nn.embedding_lookup(embedding, words)
        pos_embedder = tx.modules.SinusoidsPositionEmbedder(
            position_size = params['max_len'] + 1,
            hparams = config_model.position_embedder_hparams)
        x = (x * config_model.hidden_dim ** 0.5) + pos_embedder(sequence_length=words_len)


    with tf.variable_scope('Encoder'):
        encoder = TransformerEncoder(hparams=config_model.encoder)
        enc_out = encoder(inputs=x,
                          sequence_length=words_len,
                          mode=mode,)
        enc_state = tf.reduce_max(enc_out, axis=1)
        enc_state = tf.nn.rnn_cell.LSTMStateTuple(c=enc_state, h=enc_state)
    
    
    with tf.variable_scope('Decoder'):
        output_proj = TiedDense(embedding, len(params['char2idx'])+1)
        
        if is_training or (mode == tf.estimator.ModeKeys.EVAL):
            dec_inputs, dec_outputs = labels
            dec_seq_len = tf.count_nonzero(dec_inputs, 1, dtype=tf.int32)
            dec_inputs = tf.nn.embedding_lookup(embedding, dec_inputs)
            dec_inputs = tf.layers.dropout(dec_inputs, params['dropout_rate'], training=is_training)
            cell = dec_cell(enc_out, words_len)
            
            init_state = cell.zero_state(batch_sz, tf.float32).clone(
                cell_state=enc_state)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = dec_inputs,
                sequence_length = dec_seq_len,)
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = cell,
                helper = helper,
                initial_state = init_state,
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            
            return decoder_output.rnn_output
        else:
            enc_out_t = tf.contrib.seq2seq.tile_batch(enc_out, params['beam_width'])
            enc_state_t = tf.contrib.seq2seq.tile_batch(enc_state, params['beam_width'])
            enc_seq_len_t = tf.contrib.seq2seq.tile_batch(words_len, params['beam_width'])
            
            cell = dec_cell(enc_out_t, enc_seq_len_t)
            
            init_state = cell.zero_state(batch_sz*params['beam_width'], tf.float32).clone(
                cell_state=enc_state_t)
            
            decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
                end_token = 2,
                initial_state = init_state,
                beam_width = params['beam_width'],
                output_layer = output_proj,
                length_penalty_weight = params['length_penalty'],)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = params['max_len'],)
            
            return decoder_output.predicted_ids[:, :, :params['top_k']]

# %%
def clr(step,
        initial_learning_rate,
        maximal_learning_rate,
        step_size,
        scale_fn,
        scale_mode,):
  step = tf.cast(step, tf.float32)
  
  initial_learning_rate = tf.convert_to_tensor(
    initial_learning_rate, name='initial_learning_rate')
  dtype = initial_learning_rate.dtype
  maximal_learning_rate = tf.cast(maximal_learning_rate, dtype)
  step_size = tf.cast(step_size, dtype)
  cycle = tf.floor(1 + step / (2 * step_size))
  x = tf.abs(step / step_size - 2 * cycle + 1)

  mode_step = cycle if scale_mode == 'cycle' else step

  return initial_learning_rate + (
    maximal_learning_rate - initial_learning_rate) * tf.maximum(
      tf.cast(0, dtype), (1 - x)) * scale_fn(mode_step)

# %%
def model_fn(features, labels, mode, params):
    logits_or_ids = forward(features, labels, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
    
    dec_inputs, dec_outputs = labels
    if (params['label_smoothing'] <= .0) or (mode == tf.estimator.ModeKeys.EVAL):
      loss_op = tf.contrib.seq2seq.sequence_loss(logits = logits_or_ids,
                                                 targets = dec_outputs,
                                                 weights = tf.to_float(tf.sign(dec_outputs)))
    else:
      loss_op = tf.losses.softmax_cross_entropy(onehot_labels = tf.one_hot(dec_outputs, len(params['char2idx'])+1),
                                                logits = logits_or_ids,
                                                weights = tf.to_float(tf.sign(dec_outputs)),
                                                label_smoothing = params['label_smoothing'],)
      
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step=tf.train.get_or_create_global_step()
        
        decay_lr = clr(
          step = global_step,
          initial_learning_rate = 1e-4,
          maximal_learning_rate = 8e-4,
          step_size = params['num_samples'] // params['batch_size'],
          scale_fn=lambda x: 1 / (2.0 ** (x - 1)),
          scale_mode = 'cycle',)
        
        train_op = tf.train.AdamOptimizer(decay_lr).apply_gradients(
            clip_grads(loss_op), global_step=global_step)
        
        hook = tf.train.LoggingTensorHook({'lr': decay_lr}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[hook],)
      
    if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op)

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip('\n')
      word2idx[line] = i
  return word2idx

# %%
def pad(test_strs):
  max_len = max([len(test_str) for test_str in test_strs])
  for test_str in test_strs:
    if len(test_str) < max_len:
      test_str += ['<pad>'] * (max_len - len(test_str))


def unit_test(estimator):
  test_strs = [
    '你好',
    '早上好',
    '晚上好',
    '再见',
    '好久不见',
    '想死你了',
    '谢谢你',
    '爱你',
    '你好厉害啊',
    '你叫什么',
    '你几岁了',
    '现在几点',
    '今天天气怎么样',
    '我们现在在哪里',
    '讲个笑话',
    '你会几种语言呀',
    '你觉得我帅吗',
    '讨厌的周一',
    '好烦啊',
    '天气真好',
    '今天好冷',
    '今天好热',
    '下雨了',
    '风好大',
    '终于周五了',
    '我想去唱歌',
  ]
  test_strs = [list(test_str) for test_str in test_strs]
  pad(test_strs)
  test_arrs = [[params['char2idx'].get(c, len(params['char2idx'])) for c in test_str] for test_str in test_strs]
  predicted = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.asarray(test_arrs), shuffle = False)))
  predicted = np.asarray(predicted)
  print('-'*12)
  print('unit test')
  for i, test_str in enumerate(test_strs):
    print('Q:', ' '.join([c for c in test_str if c != '<pad>']))
    for j in range(params['top_k']):
      sent = ' '.join([params['idx2char'].get(idx, '<unk>') for idx in predicted[i, :, j] if (idx != 0 and idx != 2)])
      print('A{}:'.format(j+1), sent)
    print()
  print('-'*12)

# %%
class config_model:
    hidden_dim = 300
    num_heads = 8
    dropout_rate = .2
    num_blocks = 6

    position_embedder_hparams = {
        'dim': hidden_dim
    }

    encoder = {
        'dim': hidden_dim,
        'embedding_dropout': dropout_rate,
        'residual_dropout': dropout_rate,
        'num_blocks': num_blocks,
        'initializer': {
            'type': 'variance_scaling_initializer',
            'kwargs': {
                'scale': 1.0,
                'mode': 'fan_avg',
                'distribution': 'uniform',
            },
        },
        'multihead_attention': {
            'dropout_rate': dropout_rate,
            'num_heads': num_heads,
            'output_dim': hidden_dim,
            'use_bias': True,
        },
        'poswise_feedforward': {
          'name': 'fnn',
          'layers': [
              {
                  'type': 'Dense',
                  'kwargs': {
                      'name': 'conv1',
                      'units': hidden_dim * 4,
                      'activation': 'gelu',
                      'use_bias': True,
                  },
              },
              {
                  'type': 'Dropout',
                  'kwargs': {
                      'rate': dropout_rate,
                  }
              },
              {
                  'type': 'Dense',
                  'kwargs': {
                      'name': 'conv2',
                      'units': hidden_dim,
                      'use_bias': True,
                  }
              }
          ],
        },
    }


params = {
    'model_dir': '../model/transformer_rnn',
    'train_path': '../data/train.txt',
    'test_path': '../data/test.txt',
    'vocab_path': '../vocab/char.txt',
    'max_len': 30,
    'embed_dim': config_model.hidden_dim,
    'rnn_units': 300,
    'dec_layers': 1,
    'dropout_rate': .2,
    'beam_width': 10,
    'top_k': 3,
    'length_penalty': .0,
    'label_smoothing': .2,
    'clip_norm': 5.,
    'num_samples': 2000000,
    'buffer_size': 500000,
    'batch_size': 64,
    'num_patience': 5,
}

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['idx2char'] = {idx: char for char, idx in params['char2idx'].items()}
print(len(params['char2idx']), 'Chars')

# Create directory if not exist
Path(params['model_dir']).mkdir(exist_ok=True, parents=True)

# Logging
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

# Create an estimator
estimator = tf.estimator.Estimator(
  model_fn=model_fn,
  model_dir=params['model_dir'],
  config=tf.estimator.RunConfig(
    save_checkpoints_steps=5000, keep_checkpoint_max=1),
  params=params)

best_ppl = 10000.
count = 0
tf.enable_eager_execution()

while True:
  estimator.train(input_fn=lambda: dataset(is_training=True, params=params))

  unit_test(estimator)
  
  loss = estimator.evaluate(input_fn=lambda: dataset(is_training=False, params=params))['loss']
  ppl = np.exp(loss)
  print("Perplexity: {:.3f}".format(ppl))

  if ppl < best_ppl:
    best_ppl = ppl
    count = 0
  else:
    count += 1
  print("Best Perplexity: {:.3f}".format(best_ppl))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global_step/sec: 7.53584
# INFO:tensorflow:loss = 4.926216, step = 125800 (13.273 sec)
# INFO:tensorflow:lr = 0.00010447999 (13.275 sec)
# INFO:tensorflow:global_step/sec: 7.49769
# INFO:tensorflow:loss = 4.932872, step = 125900 (13.340 sec)
# INFO:tensorflow:lr = 0.00010504 (13.340 sec)
# INFO:tensorflow:global_step/sec: 7.51305
# INFO:tensorflow:loss = 4.7770367, step = 126000 (13.309 sec)
# INFO:tensorflow:lr = 0.00010560001 (13.308 sec)
# INFO:tensorflow:global_step/sec: 7.41466
# INFO:tensorflow:loss = 4.9139113, step = 126100 (13.485 sec)
# INFO:tensorflow:lr = 0.00010616002 (13.485 sec)
# INFO:tensorflow:global_step/sec: 7.51498
# INFO:tensorflow:loss = 4.9756117, step = 126200 (13.309 sec)
# INFO:tensorflow:lr = 0.00010672003 (13.308 sec)
# INFO:tensorflow:global_step/sec: 7.49881
# INFO:tensorflow:loss = 4.9675817, step = 126300 (13.336 sec)
# INFO:tensorflow:lr = 0.00010728004 (13.335 sec)
# INFO:tensorflow:global_step/sec: 7.59814
# INFO:tensorflow:loss = 4.7958713, step = 126400 (13.157 sec)
# INFO:tensorflow:lr = 0.000107839965 (13.160 sec)
# INFO:tensorflow:global_step/sec: 7.52405
# INFO:tensorflow:loss = 5.036263, step = 126500 (13.294 sec)
# INFO:tensorflow:lr = 0.000108399974 (13.292 sec)
# INFO:tensorflow:global_step/sec: 7.5479
# INFO:tensorflow:loss = 4.931896, step = 126600 (13.248 sec)
# INFO:tensorflow:lr = 0.00010895998 (13.249 sec)
# INFO:tensorflow:global_step/sec: 7.50586
# INFO:tensorflow:loss = 4.9268703, step = 126700 (13.325 sec)
# INFO:tensorflow:lr = 0.00010951999 (13.323 sec)
# INFO:tensorflow:global_step/sec: 7.5063
# INFO:tensorflow:loss = 4.8848166, step = 126800 (13.321 sec)
# INFO:tensorflow:lr = 0.00011008 (13.321 sec)
# INFO:tensorflow:global_step/sec: 7.52887
# INFO:tensorflow:loss = 5.080983, step = 126900 (13.283 sec)
# INFO:tensorflow:lr = 0.00011064001 (13.284 sec)
# INFO:tensorflow:global_step/sec: 7.48223
# INFO:tensorflow:loss = 4.840781, step = 127000 (13.363 sec)
# INFO:tensorflow:lr = 0.00011120002 (13.365 sec)
# INFO:tensorflow:global_step/sec: 7.53699
# INFO:tensorflow:loss = 5.0476847, step = 127100 (13.265 sec)
# INFO:tensorflow:lr = 0.00011176003 (13.266 sec)
# INFO:tensorflow:global_step/sec: 7.5102
# INFO:tensorflow:loss = 5.0100317, step = 127200 (13.320 sec)
# INFO:tensorflow:lr = 0.000112319954 (13.318 sec)
# INFO:tensorflow:global_step/sec: 7.57002
# INFO:tensorflow:loss = 4.8462143, step = 127300 (13.209 sec)
# INFO:tensorflow:lr = 0.00011287996 (13.210 sec)
# INFO:tensorflow:global_step/sec: 7.50425
# INFO:tensorflow:loss = 5.0364003, step = 127400 (13.325 sec)
# INFO:tensorflow:lr = 0.00011343997 (13.325 sec)
# INFO:tensorflow:global_step/sec: 7.60817
# INFO:tensorflow:loss = 4.9527407, step = 127500 (13.144 sec)
# INFO:tensorflow:lr = 0.00011399998 (13.144 sec)
# INFO:tensorflow:global_step/sec: 7.52076
# INFO:tensorflow:loss = 5.001379, step = 127600 (13.297 sec)
# INFO:tensorflow:lr = 0.000114559996 (13.297 sec)
# INFO:tensorflow:global_step/sec: 7.5163
# INFO:tensorflow:loss = 4.9607754, step = 127700 (13.304 sec)
# INFO:tensorflow:lr = 0.000115120005 (13.303 sec)
# INFO:tensorflow:global_step/sec: 7.50865
# INFO:tensorflow:loss = 5.163458, step = 127800 (13.315 sec)
# INFO:tensorflow:lr = 0.00011568001 (13.314 sec)
# INFO:tensorflow:global_step/sec: 7.52846
# INFO:tensorflow:loss = 5.060344, step = 127900 (13.286 sec)
# INFO:tensorflow:lr = 0.00011624002 (13.290 sec)
# INFO:tensorflow:global_step/sec: 7.49728
# INFO:tensorflow:loss = 4.876546, step = 128000 (13.335 sec)
# INFO:tensorflow:lr = 0.00011680003 (13.332 sec)
# INFO:tensorflow:global_step/sec: 7.53252
# INFO:tensorflow:loss = 4.8455253, step = 128100 (13.278 sec)
# INFO:tensorflow:lr = 0.00011735996 (13.276 sec)
# INFO:tensorflow:global_step/sec: 7.53107
# INFO:tensorflow:loss = 4.955147, step = 128200 (13.276 sec)
# INFO:tensorflow:lr = 0.00011791997 (13.277 sec)
# INFO:tensorflow:global_step/sec: 7.52993
# INFO:tensorflow:loss = 5.0082006, step = 128300 (13.282 sec)
# INFO:tensorflow:lr = 0.00011847998 (13.284 sec)
# INFO:tensorflow:global_step/sec: 7.34366
# INFO:tensorflow:loss = 4.943895, step = 128400 (13.619 sec)
# INFO:tensorflow:lr = 0.000119039985 (13.619 sec)
# INFO:tensorflow:global_step/sec: 7.49121
# INFO:tensorflow:loss = 4.961636, step = 128500 (13.350 sec)
# INFO:tensorflow:lr = 0.000119599994 (13.350 sec)
# INFO:tensorflow:global_step/sec: 7.53652
# INFO:tensorflow:loss = 5.028581, step = 128600 (13.266 sec)
# INFO:tensorflow:lr = 0.00012016 (13.266 sec)
# INFO:tensorflow:global_step/sec: 7.53153
# INFO:tensorflow:loss = 4.901879, step = 128700 (13.279 sec)
# INFO:tensorflow:lr = 0.00012072001 (13.279 sec)
# INFO:tensorflow:global_step/sec: 7.52055
# INFO:tensorflow:loss = 4.9147844, step = 128800 (13.295 sec)
# INFO:tensorflow:lr = 0.00012128003 (13.296 sec)
# INFO:tensorflow:global_step/sec: 7.56747
# INFO:tensorflow:loss = 4.9661674, step = 128900 (13.217 sec)
# INFO:tensorflow:lr = 0.00012184003 (13.216 sec)
# INFO:tensorflow:global_step/sec: 7.51984
# INFO:tensorflow:loss = 5.1622376, step = 129000 (13.296 sec)
# INFO:tensorflow:lr = 0.00012239996 (13.299 sec)
# INFO:tensorflow:global_step/sec: 7.54822
# INFO:tensorflow:loss = 4.9943395, step = 129100 (13.250 sec)
# INFO:tensorflow:lr = 0.00012295997 (13.247 sec)
# INFO:tensorflow:global_step/sec: 7.51476
# INFO:tensorflow:loss = 4.8180366, step = 129200 (13.307 sec)
# INFO:tensorflow:lr = 0.00012351997 (13.307 sec)
# INFO:tensorflow:global_step/sec: 7.51142
# INFO:tensorflow:loss = 4.9940925, step = 129300 (13.312 sec)
# INFO:tensorflow:lr = 0.00012407999 (13.315 sec)
# INFO:tensorflow:global_step/sec: 7.5156
# INFO:tensorflow:loss = 5.034844, step = 129400 (13.307 sec)
# INFO:tensorflow:lr = 0.00012463999 (13.304 sec)
# INFO:tensorflow:global_step/sec: 7.46106
# INFO:tensorflow:loss = 4.9825826, step = 129500 (13.401 sec)
# INFO:tensorflow:lr = 0.00012520001 (13.402 sec)
# INFO:tensorflow:global_step/sec: 7.44373
# INFO:tensorflow:loss = 5.114442, step = 129600 (13.435 sec)
# INFO:tensorflow:lr = 0.00012576001 (13.435 sec)
# INFO:tensorflow:global_step/sec: 7.45887
# INFO:tensorflow:loss = 4.940363, step = 129700 (13.407 sec)
# INFO:tensorflow:lr = 0.00012632002 (13.405 sec)
# INFO:tensorflow:global_step/sec: 7.43036
# INFO:tensorflow:loss = 4.865582, step = 129800 (13.460 sec)
# INFO:tensorflow:lr = 0.00012688004 (13.461 sec)
# INFO:tensorflow:global_step/sec: 7.49976
# INFO:tensorflow:loss = 5.084528, step = 129900 (13.333 sec)
# INFO:tensorflow:lr = 0.00012743995 (13.333 sec)
# INFO:tensorflow:Saving checkpoints for 130000 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.77076
# INFO:tensorflow:loss = 5.1125655, step = 130000 (14.770 sec)
# INFO:tensorflow:lr = 0.00012799997 (14.768 sec)
# INFO:tensorflow:global_step/sec: 7.29153
# INFO:tensorflow:loss = 5.0727725, step = 130100 (13.713 sec)
# INFO:tensorflow:lr = 0.00012855997 (13.713 sec)
# INFO:tensorflow:global_step/sec: 7.59645
# INFO:tensorflow:loss = 5.022838, step = 130200 (13.165 sec)
# INFO:tensorflow:lr = 0.00012911999 (13.166 sec)
# INFO:tensorflow:global_step/sec: 7.52335
# INFO:tensorflow:loss = 5.0621467, step = 130300 (13.292 sec)
# INFO:tensorflow:lr = 0.00012968 (13.291 sec)
# INFO:tensorflow:global_step/sec: 7.5067
# INFO:tensorflow:loss = 4.878237, step = 130400 (13.321 sec)
# INFO:tensorflow:lr = 0.00013024 (13.321 sec)
# INFO:tensorflow:global_step/sec: 7.5507
# INFO:tensorflow:loss = 4.998761, step = 130500 (13.242 sec)
# INFO:tensorflow:lr = 0.00013080002 (13.242 sec)
# INFO:tensorflow:global_step/sec: 7.5262
# INFO:tensorflow:loss = 4.755958, step = 130600 (13.289 sec)
# INFO:tensorflow:lr = 0.00013136002 (13.290 sec)
# INFO:tensorflow:global_step/sec: 7.41818
# INFO:tensorflow:loss = 5.135085, step = 130700 (13.484 sec)
# INFO:tensorflow:lr = 0.00013192004 (13.481 sec)
# INFO:tensorflow:global_step/sec: 7.57499
# INFO:tensorflow:loss = 4.98291, step = 130800 (13.196 sec)
# INFO:tensorflow:lr = 0.00013247997 (13.197 sec)
# INFO:tensorflow:global_step/sec: 7.55727
# INFO:tensorflow:loss = 4.993764, step = 130900 (13.237 sec)
# INFO:tensorflow:lr = 0.00013303997 (13.236 sec)
# INFO:tensorflow:global_step/sec: 7.52737
# INFO:tensorflow:loss = 4.926237, step = 131000 (13.285 sec)
# INFO:tensorflow:lr = 0.00013359998 (13.284 sec)
# INFO:tensorflow:global_step/sec: 7.61115
# INFO:tensorflow:loss = 5.021541, step = 131100 (13.137 sec)
# INFO:tensorflow:lr = 0.00013415999 (13.139 sec)
# INFO:tensorflow:global_step/sec: 7.55678
# INFO:tensorflow:loss = 5.029447, step = 131200 (13.233 sec)
# INFO:tensorflow:lr = 0.00013472 (13.232 sec)
# INFO:tensorflow:global_step/sec: 7.58294
# INFO:tensorflow:loss = 4.8068414, step = 131300 (13.188 sec)
# INFO:tensorflow:lr = 0.00013528002 (13.189 sec)
# INFO:tensorflow:global_step/sec: 7.57143
# INFO:tensorflow:loss = 5.0915546, step = 131400 (13.209 sec)
# INFO:tensorflow:lr = 0.00013584002 (13.207 sec)
# INFO:tensorflow:global_step/sec: 7.57901
# INFO:tensorflow:loss = 5.00348, step = 131500 (13.193 sec)
# INFO:tensorflow:lr = 0.00013640002 (13.195 sec)
# INFO:tensorflow:global_step/sec: 7.49769
# INFO:tensorflow:loss = 4.9442306, step = 131600 (13.336 sec)
# INFO:tensorflow:lr = 0.00013695995 (13.337 sec)
# INFO:tensorflow:global_step/sec: 7.59164
# INFO:tensorflow:loss = 5.096041, step = 131700 (13.176 sec)
# INFO:tensorflow:lr = 0.00013751996 (13.176 sec)
# INFO:tensorflow:global_step/sec: 7.58202
# INFO:tensorflow:loss = 4.8517556, step = 131800 (13.188 sec)
# INFO:tensorflow:lr = 0.00013807998 (13.186 sec)
# INFO:tensorflow:global_step/sec: 7.58411
# INFO:tensorflow:loss = 4.8006043, step = 131900 (13.186 sec)
# INFO:tensorflow:lr = 0.00013863998 (13.186 sec)
# INFO:tensorflow:global_step/sec: 7.54396
# INFO:tensorflow:loss = 4.961677, step = 132000 (13.254 sec)
# INFO:tensorflow:lr = 0.00013919998 (13.256 sec)
# INFO:tensorflow:global_step/sec: 7.54693
# INFO:tensorflow:loss = 4.8500433, step = 132100 (13.250 sec)
# INFO:tensorflow:lr = 0.00013976 (13.248 sec)
# INFO:tensorflow:global_step/sec: 7.54479
# INFO:tensorflow:loss = 4.994267, step = 132200 (13.254 sec)
# INFO:tensorflow:lr = 0.00014032001 (13.254 sec)
# INFO:tensorflow:global_step/sec: 7.55668
# INFO:tensorflow:loss = 4.7005935, step = 132300 (13.235 sec)
# INFO:tensorflow:lr = 0.00014088002 (13.234 sec)
# INFO:tensorflow:global_step/sec: 7.57284
# INFO:tensorflow:loss = 4.828643, step = 132400 (13.208 sec)
# INFO:tensorflow:lr = 0.00014144003 (13.214 sec)
# INFO:tensorflow:global_step/sec: 7.54037
# INFO:tensorflow:loss = 4.8991385, step = 132500 (13.258 sec)
# INFO:tensorflow:lr = 0.00014199996 (13.253 sec)
# INFO:tensorflow:global_step/sec: 7.51272
# INFO:tensorflow:loss = 4.9294515, step = 132600 (13.310 sec)
# INFO:tensorflow:lr = 0.00014255996 (13.310 sec)
# INFO:tensorflow:global_step/sec: 7.59028
# INFO:tensorflow:loss = 5.0237823, step = 132700 (13.177 sec)
# INFO:tensorflow:lr = 0.00014311998 (13.176 sec)
# INFO:tensorflow:global_step/sec: 7.54757
# INFO:tensorflow:loss = 4.8924403, step = 132800 (13.249 sec)
# INFO:tensorflow:lr = 0.00014367998 (13.249 sec)
# INFO:tensorflow:global_step/sec: 7.58029
# INFO:tensorflow:loss = 4.872172, step = 132900 (13.192 sec)
# INFO:tensorflow:lr = 0.00014424 (13.192 sec)
# INFO:tensorflow:global_step/sec: 7.47428
# INFO:tensorflow:loss = 4.8538756, step = 133000 (13.379 sec)
# INFO:tensorflow:lr = 0.0001448 (13.379 sec)
# INFO:tensorflow:global_step/sec: 7.44579
# INFO:tensorflow:loss = 5.0946836, step = 133100 (13.426 sec)
# INFO:tensorflow:lr = 0.00014536001 (13.427 sec)
# INFO:tensorflow:global_step/sec: 7.59377
# INFO:tensorflow:loss = 4.9607587, step = 133200 (13.171 sec)
# INFO:tensorflow:lr = 0.00014592003 (13.171 sec)
# INFO:tensorflow:global_step/sec: 7.55108
# INFO:tensorflow:loss = 4.9501286, step = 133300 (13.241 sec)
# INFO:tensorflow:lr = 0.00014648003 (13.240 sec)
# INFO:tensorflow:global_step/sec: 7.51405
# INFO:tensorflow:loss = 4.992131, step = 133400 (13.310 sec)
# INFO:tensorflow:lr = 0.00014703996 (13.311 sec)
# INFO:tensorflow:global_step/sec: 7.59109
# INFO:tensorflow:loss = 4.9593444, step = 133500 (13.174 sec)
# INFO:tensorflow:lr = 0.00014759996 (13.173 sec)
# INFO:tensorflow:global_step/sec: 7.58398
# INFO:tensorflow:loss = 4.8623424, step = 133600 (13.183 sec)
# INFO:tensorflow:lr = 0.00014815998 (13.183 sec)
# INFO:tensorflow:global_step/sec: 7.58254
# INFO:tensorflow:loss = 4.886888, step = 133700 (13.193 sec)
# INFO:tensorflow:lr = 0.00014871999 (13.192 sec)
# INFO:tensorflow:global_step/sec: 7.55042
# INFO:tensorflow:loss = 4.9518247, step = 133800 (13.244 sec)
# INFO:tensorflow:lr = 0.00014928 (13.244 sec)
# INFO:tensorflow:global_step/sec: 7.53963
# INFO:tensorflow:loss = 5.084045, step = 133900 (13.269 sec)
# INFO:tensorflow:lr = 0.00014984001 (13.269 sec)
# INFO:tensorflow:global_step/sec: 7.54969
# INFO:tensorflow:loss = 4.913486, step = 134000 (13.239 sec)
# INFO:tensorflow:lr = 0.00015040001 (13.240 sec)
# INFO:tensorflow:global_step/sec: 7.59686
# INFO:tensorflow:loss = 4.927879, step = 134100 (13.163 sec)
# INFO:tensorflow:lr = 0.00015096003 (13.163 sec)
# INFO:tensorflow:global_step/sec: 7.56652
# INFO:tensorflow:loss = 4.866723, step = 134200 (13.213 sec)
# INFO:tensorflow:lr = 0.00015152004 (13.212 sec)
# INFO:tensorflow:global_step/sec: 7.55406
# INFO:tensorflow:loss = 4.8933287, step = 134300 (13.238 sec)
# INFO:tensorflow:lr = 0.00015207996 (13.239 sec)
# INFO:tensorflow:global_step/sec: 7.62815
# INFO:tensorflow:loss = 4.889435, step = 134400 (13.113 sec)
# INFO:tensorflow:lr = 0.00015263997 (13.112 sec)
# INFO:tensorflow:global_step/sec: 7.59262
# INFO:tensorflow:loss = 4.9912734, step = 134500 (13.169 sec)
# INFO:tensorflow:lr = 0.00015319997 (13.168 sec)
# INFO:tensorflow:global_step/sec: 7.54563
# INFO:tensorflow:loss = 4.8976274, step = 134600 (13.255 sec)
# INFO:tensorflow:lr = 0.00015375999 (13.255 sec)
# INFO:tensorflow:global_step/sec: 7.51791
# INFO:tensorflow:loss = 4.981569, step = 134700 (13.299 sec)
# INFO:tensorflow:lr = 0.00015432 (13.302 sec)
# INFO:tensorflow:global_step/sec: 7.56647
# INFO:tensorflow:loss = 4.913983, step = 134800 (13.217 sec)
# INFO:tensorflow:lr = 0.00015488 (13.215 sec)
# INFO:tensorflow:global_step/sec: 7.5322
# INFO:tensorflow:loss = 4.9004145, step = 134900 (13.280 sec)
# INFO:tensorflow:lr = 0.00015544001 (13.278 sec)
# INFO:tensorflow:Saving checkpoints for 135000 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.01015
# INFO:tensorflow:loss = 5.0733156, step = 135000 (14.262 sec)
# INFO:tensorflow:lr = 0.00015600002 (14.263 sec)
# INFO:tensorflow:global_step/sec: 7.30784
# INFO:tensorflow:loss = 4.922636, step = 135100 (13.685 sec)
# INFO:tensorflow:lr = 0.00015656004 (13.684 sec)
# INFO:tensorflow:global_step/sec: 7.53832
# INFO:tensorflow:loss = 4.9904747, step = 135200 (13.265 sec)
# INFO:tensorflow:lr = 0.00015711997 (13.267 sec)
# INFO:tensorflow:global_step/sec: 7.57611
# INFO:tensorflow:loss = 4.89587, step = 135300 (13.201 sec)
# INFO:tensorflow:lr = 0.00015767997 (13.199 sec)
# INFO:tensorflow:global_step/sec: 7.3802
# INFO:tensorflow:loss = 4.977661, step = 135400 (13.548 sec)
# INFO:tensorflow:lr = 0.00015823997 (13.549 sec)
# INFO:tensorflow:global_step/sec: 7.55553
# INFO:tensorflow:loss = 4.996764, step = 135500 (13.235 sec)
# INFO:tensorflow:lr = 0.00015879999 (13.236 sec)
# INFO:tensorflow:global_step/sec: 7.57763
# INFO:tensorflow:loss = 4.994336, step = 135600 (13.202 sec)
# INFO:tensorflow:lr = 0.00015936 (13.202 sec)
# INFO:tensorflow:global_step/sec: 7.56623
# INFO:tensorflow:loss = 4.933366, step = 135700 (13.210 sec)
# INFO:tensorflow:lr = 0.00015992 (13.209 sec)
# INFO:tensorflow:global_step/sec: 7.53156
# INFO:tensorflow:loss = 4.980471, step = 135800 (13.280 sec)
# INFO:tensorflow:lr = 0.00016048002 (13.281 sec)
# INFO:tensorflow:global_step/sec: 7.57462
# INFO:tensorflow:loss = 5.0202627, step = 135900 (13.203 sec)
# INFO:tensorflow:lr = 0.00016104002 (13.202 sec)
# INFO:tensorflow:global_step/sec: 7.59227
# INFO:tensorflow:loss = 4.958462, step = 136000 (13.170 sec)
# INFO:tensorflow:lr = 0.00016159995 (13.172 sec)
# INFO:tensorflow:global_step/sec: 7.59104
# INFO:tensorflow:loss = 4.9666886, step = 136100 (13.175 sec)
# INFO:tensorflow:lr = 0.00016215997 (13.174 sec)
# INFO:tensorflow:global_step/sec: 7.47426
# INFO:tensorflow:loss = 4.994348, step = 136200 (13.380 sec)
# INFO:tensorflow:lr = 0.00016271998 (13.378 sec)
# INFO:tensorflow:global_step/sec: 7.55607
# INFO:tensorflow:loss = 4.946134, step = 136300 (13.232 sec)
# INFO:tensorflow:lr = 0.00016327998 (13.232 sec)
# INFO:tensorflow:global_step/sec: 7.53546
# INFO:tensorflow:loss = 5.0004935, step = 136400 (13.275 sec)
# INFO:tensorflow:lr = 0.00016383998 (13.274 sec)
# INFO:tensorflow:global_step/sec: 7.52213
# INFO:tensorflow:loss = 5.1107297, step = 136500 (13.290 sec)
# INFO:tensorflow:lr = 0.0001644 (13.290 sec)
# INFO:tensorflow:global_step/sec: 7.51563
# INFO:tensorflow:loss = 4.9258676, step = 136600 (13.305 sec)
# INFO:tensorflow:lr = 0.00016496002 (13.306 sec)
# INFO:tensorflow:global_step/sec: 7.52939
# INFO:tensorflow:loss = 4.8528786, step = 136700 (13.284 sec)
# INFO:tensorflow:lr = 0.00016552002 (13.284 sec)
# INFO:tensorflow:global_step/sec: 7.53227
# INFO:tensorflow:loss = 4.951685, step = 136800 (13.274 sec)
# INFO:tensorflow:lr = 0.00016608002 (13.275 sec)
# INFO:tensorflow:global_step/sec: 7.55996
# INFO:tensorflow:loss = 4.9882092, step = 136900 (13.229 sec)
# INFO:tensorflow:lr = 0.00016663995 (13.229 sec)
# INFO:tensorflow:global_step/sec: 7.51474
# INFO:tensorflow:loss = 4.795229, step = 137000 (13.304 sec)
# INFO:tensorflow:lr = 0.00016719996 (13.303 sec)
# INFO:tensorflow:global_step/sec: 7.5131
# INFO:tensorflow:loss = 4.924183, step = 137100 (13.313 sec)
# INFO:tensorflow:lr = 0.00016775998 (13.314 sec)
# INFO:tensorflow:global_step/sec: 7.5765
# INFO:tensorflow:loss = 5.081997, step = 137200 (13.196 sec)
# INFO:tensorflow:lr = 0.00016831998 (13.195 sec)
# INFO:tensorflow:global_step/sec: 7.57607
# INFO:tensorflow:loss = 4.9213266, step = 137300 (13.202 sec)
# INFO:tensorflow:lr = 0.00016887998 (13.202 sec)
# INFO:tensorflow:global_step/sec: 7.58075
# INFO:tensorflow:loss = 4.885973, step = 137400 (13.190 sec)
# INFO:tensorflow:lr = 0.00016944 (13.191 sec)
# INFO:tensorflow:global_step/sec: 7.57278
# INFO:tensorflow:loss = 4.987309, step = 137500 (13.207 sec)
# INFO:tensorflow:lr = 0.00017000001 (13.207 sec)
# INFO:tensorflow:global_step/sec: 7.51894
# INFO:tensorflow:loss = 4.819464, step = 137600 (13.302 sec)
# INFO:tensorflow:lr = 0.00017056003 (13.301 sec)
# INFO:tensorflow:global_step/sec: 7.44758
# INFO:tensorflow:loss = 5.0284004, step = 137700 (13.425 sec)
# INFO:tensorflow:lr = 0.00017112003 (13.426 sec)
# INFO:tensorflow:global_step/sec: 7.54223
# INFO:tensorflow:loss = 4.845201, step = 137800 (13.256 sec)
# INFO:tensorflow:lr = 0.00017167996 (13.256 sec)
# INFO:tensorflow:global_step/sec: 7.55734
# INFO:tensorflow:loss = 5.0980706, step = 137900 (13.233 sec)
# INFO:tensorflow:lr = 0.00017223996 (13.234 sec)
# INFO:tensorflow:global_step/sec: 7.46874
# INFO:tensorflow:loss = 5.0311766, step = 138000 (13.391 sec)
# INFO:tensorflow:lr = 0.00017279998 (13.390 sec)
# INFO:tensorflow:global_step/sec: 7.46846
# INFO:tensorflow:loss = 4.975446, step = 138100 (13.388 sec)
# INFO:tensorflow:lr = 0.00017336 (13.389 sec)
# INFO:tensorflow:global_step/sec: 7.49211
# INFO:tensorflow:loss = 4.975305, step = 138200 (13.350 sec)
# INFO:tensorflow:lr = 0.00017392 (13.349 sec)
# INFO:tensorflow:global_step/sec: 7.49509
# INFO:tensorflow:loss = 4.846656, step = 138300 (13.341 sec)
# INFO:tensorflow:lr = 0.00017448 (13.341 sec)
# INFO:tensorflow:global_step/sec: 7.46158
# INFO:tensorflow:loss = 4.8620996, step = 138400 (13.403 sec)
# INFO:tensorflow:lr = 0.00017504001 (13.403 sec)
# INFO:tensorflow:global_step/sec: 7.42924
# INFO:tensorflow:loss = 4.9500613, step = 138500 (13.460 sec)
# INFO:tensorflow:lr = 0.00017560003 (13.461 sec)
# INFO:tensorflow:global_step/sec: 7.55573
# INFO:tensorflow:loss = 5.011314, step = 138600 (13.233 sec)
# INFO:tensorflow:lr = 0.00017616003 (13.233 sec)
# INFO:tensorflow:global_step/sec: 7.57241
# INFO:tensorflow:loss = 4.8212366, step = 138700 (13.207 sec)
# INFO:tensorflow:lr = 0.00017671996 (13.206 sec)
# INFO:tensorflow:global_step/sec: 7.53493
# INFO:tensorflow:loss = 4.9582305, step = 138800 (13.272 sec)
# INFO:tensorflow:lr = 0.00017727996 (13.273 sec)
# INFO:tensorflow:global_step/sec: 7.53755
# INFO:tensorflow:loss = 5.107563, step = 138900 (13.263 sec)
# INFO:tensorflow:lr = 0.00017783997 (13.265 sec)
# INFO:tensorflow:global_step/sec: 7.62296
# INFO:tensorflow:loss = 4.940448, step = 139000 (13.120 sec)
# INFO:tensorflow:lr = 0.00017839999 (13.118 sec)
# INFO:tensorflow:global_step/sec: 7.60442
# INFO:tensorflow:loss = 4.885955, step = 139100 (13.151 sec)
# INFO:tensorflow:lr = 0.00017896 (13.150 sec)
# INFO:tensorflow:global_step/sec: 7.56299
# INFO:tensorflow:loss = 4.9432116, step = 139200 (13.222 sec)
# INFO:tensorflow:lr = 0.00017952001 (13.224 sec)
# INFO:tensorflow:global_step/sec: 7.55132
# INFO:tensorflow:loss = 5.0291095, step = 139300 (13.245 sec)
# INFO:tensorflow:lr = 0.00018008001 (13.243 sec)
# INFO:tensorflow:global_step/sec: 7.53164
# INFO:tensorflow:loss = 5.0215664, step = 139400 (13.276 sec)
# INFO:tensorflow:lr = 0.00018064003 (13.277 sec)
# INFO:tensorflow:global_step/sec: 7.54445
# INFO:tensorflow:loss = 5.0752277, step = 139500 (13.257 sec)
# INFO:tensorflow:lr = 0.00018120004 (13.255 sec)
# INFO:tensorflow:global_step/sec: 7.58194
# INFO:tensorflow:loss = 5.035188, step = 139600 (13.188 sec)
# INFO:tensorflow:lr = 0.00018175997 (13.189 sec)
# INFO:tensorflow:global_step/sec: 7.52948
# INFO:tensorflow:loss = 4.9523716, step = 139700 (13.279 sec)
# INFO:tensorflow:lr = 0.00018231997 (13.280 sec)
# INFO:tensorflow:global_step/sec: 7.55317
# INFO:tensorflow:loss = 4.911041, step = 139800 (13.241 sec)
# INFO:tensorflow:lr = 0.00018287997 (13.239 sec)
# INFO:tensorflow:global_step/sec: 7.5238
# INFO:tensorflow:loss = 4.9281373, step = 139900 (13.291 sec)
# INFO:tensorflow:lr = 0.00018343999 (13.292 sec)
# INFO:tensorflow:Saving checkpoints for 140000 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.92097
# INFO:tensorflow:loss = 4.9092565, step = 140000 (14.448 sec)
# INFO:tensorflow:lr = 0.000184 (14.447 sec)
# INFO:tensorflow:global_step/sec: 7.12749
# INFO:tensorflow:loss = 5.1673, step = 140100 (14.031 sec)
# INFO:tensorflow:lr = 0.00018456 (14.032 sec)
# INFO:tensorflow:global_step/sec: 7.41853
# INFO:tensorflow:loss = 4.864843, step = 140200 (13.478 sec)
# INFO:tensorflow:lr = 0.00018512 (13.479 sec)
# INFO:tensorflow:global_step/sec: 7.46807
# INFO:tensorflow:loss = 4.984541, step = 140300 (13.390 sec)
# INFO:tensorflow:lr = 0.00018568002 (13.391 sec)
# INFO:tensorflow:global_step/sec: 7.46367
# INFO:tensorflow:loss = 5.115975, step = 140400 (13.400 sec)
# INFO:tensorflow:lr = 0.00018623995 (13.398 sec)
# INFO:tensorflow:global_step/sec: 7.5044
# INFO:tensorflow:loss = 5.0524063, step = 140500 (13.324 sec)
# INFO:tensorflow:lr = 0.00018679997 (13.323 sec)
# INFO:tensorflow:global_step/sec: 7.44403
# INFO:tensorflow:loss = 4.964694, step = 140600 (13.445 sec)
# INFO:tensorflow:lr = 0.00018735997 (13.445 sec)
# INFO:tensorflow:global_step/sec: 7.43825
# INFO:tensorflow:loss = 4.993907, step = 140700 (13.434 sec)
# INFO:tensorflow:lr = 0.00018791997 (13.436 sec)
# INFO:tensorflow:global_step/sec: 7.46386
# INFO:tensorflow:loss = 4.9305606, step = 140800 (13.399 sec)
# INFO:tensorflow:lr = 0.00018847999 (13.399 sec)
# INFO:tensorflow:global_step/sec: 7.51135
# INFO:tensorflow:loss = 4.9753523, step = 140900 (13.309 sec)
# INFO:tensorflow:lr = 0.00018904 (13.309 sec)
# INFO:tensorflow:global_step/sec: 7.52239
# INFO:tensorflow:loss = 4.9872537, step = 141000 (13.295 sec)
# INFO:tensorflow:lr = 0.00018960002 (13.295 sec)
# INFO:tensorflow:global_step/sec: 7.46868
# INFO:tensorflow:loss = 4.977306, step = 141100 (13.390 sec)
# INFO:tensorflow:lr = 0.00019016002 (13.390 sec)
# INFO:tensorflow:global_step/sec: 7.46862
# INFO:tensorflow:loss = 4.9802876, step = 141200 (13.390 sec)
# INFO:tensorflow:lr = 0.00019072002 (13.390 sec)
# INFO:tensorflow:global_step/sec: 7.48507
# INFO:tensorflow:loss = 4.9962134, step = 141300 (13.362 sec)
# INFO:tensorflow:lr = 0.00019127995 (13.361 sec)
# INFO:tensorflow:global_step/sec: 7.4996
# INFO:tensorflow:loss = 4.831175, step = 141400 (13.331 sec)
# INFO:tensorflow:lr = 0.00019183996 (13.332 sec)
# INFO:tensorflow:global_step/sec: 7.48781
# INFO:tensorflow:loss = 4.959976, step = 141500 (13.361 sec)
# INFO:tensorflow:lr = 0.00019239998 (13.360 sec)
# INFO:tensorflow:global_step/sec: 7.52416
# INFO:tensorflow:loss = 5.0693455, step = 141600 (13.285 sec)
# INFO:tensorflow:lr = 0.00019295998 (13.288 sec)
# INFO:tensorflow:global_step/sec: 7.5123
# INFO:tensorflow:loss = 4.9908442, step = 141700 (13.309 sec)
# INFO:tensorflow:lr = 0.00019351998 (13.309 sec)
# INFO:tensorflow:global_step/sec: 7.50321
# INFO:tensorflow:loss = 4.9782867, step = 141800 (13.330 sec)
# INFO:tensorflow:lr = 0.00019408 (13.329 sec)
# INFO:tensorflow:global_step/sec: 7.51786
# INFO:tensorflow:loss = 5.0002356, step = 141900 (13.304 sec)
# INFO:tensorflow:lr = 0.00019464002 (13.302 sec)
# INFO:tensorflow:global_step/sec: 7.51725
# INFO:tensorflow:loss = 4.87068, step = 142000 (13.303 sec)
# INFO:tensorflow:lr = 0.00019520002 (13.304 sec)
# INFO:tensorflow:global_step/sec: 7.52272
# INFO:tensorflow:loss = 4.9190655, step = 142100 (13.291 sec)
# INFO:tensorflow:lr = 0.00019576003 (13.291 sec)
# INFO:tensorflow:global_step/sec: 7.52894
# INFO:tensorflow:loss = 4.906983, step = 142200 (13.282 sec)
# INFO:tensorflow:lr = 0.00019631995 (13.281 sec)
# INFO:tensorflow:global_step/sec: 7.5098
# INFO:tensorflow:loss = 4.879544, step = 142300 (13.316 sec)
# INFO:tensorflow:lr = 0.00019687996 (13.318 sec)
# INFO:tensorflow:global_step/sec: 7.31062
# INFO:tensorflow:loss = 5.0100584, step = 142400 (13.680 sec)
# INFO:tensorflow:lr = 0.00019743998 (13.680 sec)
# INFO:tensorflow:global_step/sec: 7.46391
# INFO:tensorflow:loss = 4.996681, step = 142500 (13.398 sec)
# INFO:tensorflow:lr = 0.000198 (13.397 sec)
# INFO:tensorflow:global_step/sec: 7.51917
# INFO:tensorflow:loss = 5.0055585, step = 142600 (13.296 sec)
# INFO:tensorflow:lr = 0.00019856 (13.297 sec)
# INFO:tensorflow:global_step/sec: 7.49565
# INFO:tensorflow:loss = 4.860406, step = 142700 (13.344 sec)
# INFO:tensorflow:lr = 0.00019912 (13.344 sec)
# INFO:tensorflow:global_step/sec: 7.53226
# INFO:tensorflow:loss = 4.921631, step = 142800 (13.275 sec)
# INFO:tensorflow:lr = 0.00019968001 (13.275 sec)
# INFO:tensorflow:global_step/sec: 7.51327
# INFO:tensorflow:loss = 5.070619, step = 142900 (13.312 sec)
# INFO:tensorflow:lr = 0.00020024003 (13.312 sec)
# INFO:tensorflow:global_step/sec: 7.46532
# INFO:tensorflow:loss = 4.881922, step = 143000 (13.397 sec)
# INFO:tensorflow:lr = 0.00020080003 (13.396 sec)
# INFO:tensorflow:global_step/sec: 7.4512
# INFO:tensorflow:loss = 5.080689, step = 143100 (13.418 sec)
# INFO:tensorflow:lr = 0.00020135996 (13.420 sec)
# INFO:tensorflow:global_step/sec: 7.50852
# INFO:tensorflow:loss = 4.962821, step = 143200 (13.318 sec)
# INFO:tensorflow:lr = 0.00020191996 (13.317 sec)
# INFO:tensorflow:global_step/sec: 7.492
# INFO:tensorflow:loss = 5.0488467, step = 143300 (13.348 sec)
# INFO:tensorflow:lr = 0.00020247998 (13.349 sec)
# INFO:tensorflow:global_step/sec: 7.53086
# INFO:tensorflow:loss = 4.9634376, step = 143400 (13.276 sec)
# INFO:tensorflow:lr = 0.00020303999 (13.275 sec)
# INFO:tensorflow:global_step/sec: 7.50938
# INFO:tensorflow:loss = 4.7577677, step = 143500 (13.320 sec)
# INFO:tensorflow:lr = 0.0002036 (13.320 sec)
# INFO:tensorflow:global_step/sec: 7.52692
# INFO:tensorflow:loss = 4.961926, step = 143600 (13.287 sec)
# INFO:tensorflow:lr = 0.00020416 (13.286 sec)
# INFO:tensorflow:global_step/sec: 7.5039
# INFO:tensorflow:loss = 4.767165, step = 143700 (13.324 sec)
# INFO:tensorflow:lr = 0.00020472001 (13.327 sec)
# INFO:tensorflow:global_step/sec: 7.44806
# INFO:tensorflow:loss = 5.097906, step = 143800 (13.427 sec)
# INFO:tensorflow:lr = 0.00020528003 (13.425 sec)
# INFO:tensorflow:global_step/sec: 7.48937
# INFO:tensorflow:loss = 4.845003, step = 143900 (13.352 sec)
# INFO:tensorflow:lr = 0.00020584004 (13.353 sec)
# INFO:tensorflow:global_step/sec: 7.5715
# INFO:tensorflow:loss = 5.062029, step = 144000 (13.207 sec)
# INFO:tensorflow:lr = 0.00020639996 (13.206 sec)
# INFO:tensorflow:global_step/sec: 7.54723
# INFO:tensorflow:loss = 4.992302, step = 144100 (13.249 sec)
# INFO:tensorflow:lr = 0.00020695996 (13.249 sec)
# INFO:tensorflow:global_step/sec: 7.49797
# INFO:tensorflow:loss = 4.939758, step = 144200 (13.337 sec)
# INFO:tensorflow:lr = 0.00020751997 (13.341 sec)
# INFO:tensorflow:global_step/sec: 7.4906
# INFO:tensorflow:loss = 4.885959, step = 144300 (13.350 sec)
# INFO:tensorflow:lr = 0.00020807999 (13.347 sec)
# INFO:tensorflow:global_step/sec: 7.54563
# INFO:tensorflow:loss = 4.9403205, step = 144400 (13.255 sec)
# INFO:tensorflow:lr = 0.00020864 (13.254 sec)
# INFO:tensorflow:global_step/sec: 7.5366
# INFO:tensorflow:loss = 4.820284, step = 144500 (13.268 sec)
# INFO:tensorflow:lr = 0.0002092 (13.267 sec)
# INFO:tensorflow:global_step/sec: 7.51839
# INFO:tensorflow:loss = 5.070644, step = 144600 (13.299 sec)
# INFO:tensorflow:lr = 0.00020976001 (13.301 sec)
# INFO:tensorflow:global_step/sec: 7.40379
# INFO:tensorflow:loss = 5.1978683, step = 144700 (13.507 sec)
# INFO:tensorflow:lr = 0.00021032002 (13.508 sec)
# INFO:tensorflow:global_step/sec: 7.46561
# INFO:tensorflow:loss = 5.081166, step = 144800 (13.393 sec)
# INFO:tensorflow:lr = 0.00021087995 (13.392 sec)
# INFO:tensorflow:global_step/sec: 7.54177
# INFO:tensorflow:loss = 4.899738, step = 144900 (13.263 sec)
# INFO:tensorflow:lr = 0.00021143997 (13.262 sec)
# INFO:tensorflow:Saving checkpoints for 145000 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.75266
# INFO:tensorflow:loss = 4.91447, step = 145000 (14.808 sec)
# INFO:tensorflow:lr = 0.00021199997 (14.809 sec)
# INFO:tensorflow:global_step/sec: 7.2911
# INFO:tensorflow:loss = 4.9235835, step = 145100 (13.715 sec)
# INFO:tensorflow:lr = 0.00021255997 (13.716 sec)
# INFO:tensorflow:global_step/sec: 7.57054
# INFO:tensorflow:loss = 4.9860587, step = 145200 (13.207 sec)
# INFO:tensorflow:lr = 0.00021311999 (13.210 sec)
# INFO:tensorflow:global_step/sec: 7.50656
# INFO:tensorflow:loss = 5.0278087, step = 145300 (13.320 sec)
# INFO:tensorflow:lr = 0.00021368 (13.320 sec)
# INFO:tensorflow:global_step/sec: 7.50232
# INFO:tensorflow:loss = 4.9481883, step = 145400 (13.332 sec)
# INFO:tensorflow:lr = 0.00021424 (13.329 sec)
# INFO:tensorflow:global_step/sec: 7.53284
# INFO:tensorflow:loss = 5.064481, step = 145500 (13.275 sec)
# INFO:tensorflow:lr = 0.00021480002 (13.274 sec)
# INFO:tensorflow:global_step/sec: 7.53134
# INFO:tensorflow:loss = 5.1132703, step = 145600 (13.279 sec)
# INFO:tensorflow:lr = 0.00021536002 (13.280 sec)
# INFO:tensorflow:global_step/sec: 7.57706
# INFO:tensorflow:loss = 4.9717927, step = 145700 (13.195 sec)
# INFO:tensorflow:lr = 0.00021591995 (13.197 sec)
# INFO:tensorflow:global_step/sec: 7.54394
# INFO:tensorflow:loss = 4.913138, step = 145800 (13.259 sec)
# INFO:tensorflow:lr = 0.00021647997 (13.256 sec)
# INFO:tensorflow:global_step/sec: 7.54623
# INFO:tensorflow:loss = 4.825306, step = 145900 (13.256 sec)
# INFO:tensorflow:lr = 0.00021703998 (13.255 sec)
# INFO:tensorflow:global_step/sec: 7.58428
# INFO:tensorflow:loss = 4.9375834, step = 146000 (13.182 sec)
# INFO:tensorflow:lr = 0.00021759998 (13.182 sec)
# INFO:tensorflow:global_step/sec: 7.51504
# INFO:tensorflow:loss = 4.954141, step = 146100 (13.308 sec)
# INFO:tensorflow:lr = 0.00021815998 (13.308 sec)
# INFO:tensorflow:global_step/sec: 7.59319
# INFO:tensorflow:loss = 4.9399867, step = 146200 (13.165 sec)
# INFO:tensorflow:lr = 0.00021872 (13.166 sec)
# INFO:tensorflow:global_step/sec: 7.59405
# INFO:tensorflow:loss = 4.9553647, step = 146300 (13.171 sec)
# INFO:tensorflow:lr = 0.00021928002 (13.171 sec)
# INFO:tensorflow:global_step/sec: 7.54148
# INFO:tensorflow:loss = 4.919226, step = 146400 (13.261 sec)
# INFO:tensorflow:lr = 0.00021984002 (13.261 sec)
# INFO:tensorflow:global_step/sec: 7.51919
# INFO:tensorflow:loss = 5.052667, step = 146500 (13.299 sec)
# INFO:tensorflow:lr = 0.00022040002 (13.299 sec)
# INFO:tensorflow:global_step/sec: 7.53875
# INFO:tensorflow:loss = 4.8802, step = 146600 (13.261 sec)
# INFO:tensorflow:lr = 0.00022095995 (13.261 sec)
# INFO:tensorflow:global_step/sec: 7.52712
# INFO:tensorflow:loss = 4.927078, step = 146700 (13.285 sec)
# INFO:tensorflow:lr = 0.00022151996 (13.286 sec)
# INFO:tensorflow:global_step/sec: 7.55248
# INFO:tensorflow:loss = 5.016589, step = 146800 (13.243 sec)
# INFO:tensorflow:lr = 0.00022207998 (13.242 sec)
# INFO:tensorflow:global_step/sec: 7.49533
# INFO:tensorflow:loss = 4.962419, step = 146900 (13.344 sec)
# INFO:tensorflow:lr = 0.00022264 (13.343 sec)
# INFO:tensorflow:global_step/sec: 7.39538
# INFO:tensorflow:loss = 4.875701, step = 147000 (13.519 sec)
# INFO:tensorflow:lr = 0.00022319998 (13.521 sec)
# INFO:tensorflow:global_step/sec: 7.39462
# INFO:tensorflow:loss = 4.972998, step = 147100 (13.525 sec)
# INFO:tensorflow:lr = 0.00022376 (13.524 sec)
# INFO:tensorflow:global_step/sec: 7.5102
# INFO:tensorflow:loss = 5.0024166, step = 147200 (13.315 sec)
# INFO:tensorflow:lr = 0.00022432001 (13.315 sec)
# INFO:tensorflow:global_step/sec: 7.52313
# INFO:tensorflow:loss = 4.8923373, step = 147300 (13.291 sec)
# INFO:tensorflow:lr = 0.00022488003 (13.292 sec)
# INFO:tensorflow:global_step/sec: 7.50608
# INFO:tensorflow:loss = 4.920726, step = 147400 (13.325 sec)
# INFO:tensorflow:lr = 0.00022544002 (13.323 sec)
# INFO:tensorflow:global_step/sec: 7.53358
# INFO:tensorflow:loss = 4.917851, step = 147500 (13.272 sec)
# INFO:tensorflow:lr = 0.00022599995 (13.273 sec)
# INFO:tensorflow:global_step/sec: 7.48301
# INFO:tensorflow:loss = 4.978604, step = 147600 (13.360 sec)
# INFO:tensorflow:lr = 0.00022655996 (13.363 sec)
# INFO:tensorflow:global_step/sec: 7.50938
# INFO:tensorflow:loss = 4.801969, step = 147700 (13.321 sec)
# INFO:tensorflow:lr = 0.00022711998 (13.318 sec)
# INFO:tensorflow:global_step/sec: 7.51936
# INFO:tensorflow:loss = 4.8688154, step = 147800 (13.298 sec)
# INFO:tensorflow:lr = 0.00022768 (13.299 sec)
# INFO:tensorflow:global_step/sec: 7.49028
# INFO:tensorflow:loss = 5.108317, step = 147900 (13.348 sec)
# INFO:tensorflow:lr = 0.00022823998 (13.350 sec)
# INFO:tensorflow:global_step/sec: 7.56235
# INFO:tensorflow:loss = 4.9885406, step = 148000 (13.223 sec)
# INFO:tensorflow:lr = 0.0002288 (13.221 sec)
# INFO:tensorflow:global_step/sec: 7.52888
# INFO:tensorflow:loss = 4.8271627, step = 148100 (13.286 sec)
# INFO:tensorflow:lr = 0.00022936001 (13.287 sec)
# INFO:tensorflow:global_step/sec: 7.58214
# INFO:tensorflow:loss = 5.103774, step = 148200 (13.189 sec)
# INFO:tensorflow:lr = 0.00022992003 (13.188 sec)
# INFO:tensorflow:global_step/sec: 7.56255
# INFO:tensorflow:loss = 4.969439, step = 148300 (13.221 sec)
# INFO:tensorflow:lr = 0.00023048004 (13.221 sec)
# INFO:tensorflow:global_step/sec: 7.59323
# INFO:tensorflow:loss = 4.925897, step = 148400 (13.170 sec)
# INFO:tensorflow:lr = 0.00023103997 (13.171 sec)
# INFO:tensorflow:global_step/sec: 7.75704
# INFO:tensorflow:loss = 4.9991937, step = 148500 (12.889 sec)
# INFO:tensorflow:lr = 0.00023159996 (12.891 sec)
# INFO:tensorflow:global_step/sec: 7.8993
# INFO:tensorflow:loss = 5.0679235, step = 148600 (12.660 sec)
# INFO:tensorflow:lr = 0.00023215997 (12.657 sec)
# INFO:tensorflow:global_step/sec: 7.89578
# INFO:tensorflow:loss = 4.829716, step = 148700 (12.665 sec)
# INFO:tensorflow:lr = 0.00023271999 (12.665 sec)
# INFO:tensorflow:global_step/sec: 7.8811
# INFO:tensorflow:loss = 4.8206515, step = 148800 (12.692 sec)
# INFO:tensorflow:lr = 0.00023328 (12.691 sec)
# INFO:tensorflow:global_step/sec: 7.9248
# INFO:tensorflow:loss = 4.972184, step = 148900 (12.620 sec)
# INFO:tensorflow:lr = 0.00023384 (12.620 sec)
# INFO:tensorflow:global_step/sec: 7.96783
# INFO:tensorflow:loss = 4.9503756, step = 149000 (12.552 sec)
# INFO:tensorflow:lr = 0.00023440001 (12.552 sec)
# INFO:tensorflow:global_step/sec: 7.89725
# INFO:tensorflow:loss = 5.0174217, step = 149100 (12.659 sec)
# INFO:tensorflow:lr = 0.00023496003 (12.660 sec)
# INFO:tensorflow:global_step/sec: 7.90019
# INFO:tensorflow:loss = 4.90376, step = 149200 (12.659 sec)
# INFO:tensorflow:lr = 0.00023551995 (12.659 sec)
# INFO:tensorflow:global_step/sec: 7.87931
# INFO:tensorflow:loss = 4.908426, step = 149300 (12.692 sec)
# INFO:tensorflow:lr = 0.00023607997 (12.692 sec)
# INFO:tensorflow:global_step/sec: 7.78531
# INFO:tensorflow:loss = 4.9825315, step = 149400 (12.842 sec)
# INFO:tensorflow:lr = 0.00023663996 (12.844 sec)
# INFO:tensorflow:global_step/sec: 7.8698
# INFO:tensorflow:loss = 4.8064737, step = 149500 (12.706 sec)
# INFO:tensorflow:lr = 0.00023719997 (12.708 sec)
# INFO:tensorflow:global_step/sec: 7.94956
# INFO:tensorflow:loss = 4.997615, step = 149600 (12.582 sec)
# INFO:tensorflow:lr = 0.00023775999 (12.580 sec)
# INFO:tensorflow:global_step/sec: 7.90278
# INFO:tensorflow:loss = 5.007567, step = 149700 (12.654 sec)
# INFO:tensorflow:lr = 0.00023832 (12.653 sec)
# INFO:tensorflow:global_step/sec: 7.91213
# INFO:tensorflow:loss = 5.0222683, step = 149800 (12.637 sec)
# INFO:tensorflow:lr = 0.00023888002 (12.639 sec)
# INFO:tensorflow:global_step/sec: 8.01029
# INFO:tensorflow:loss = 4.980418, step = 149900 (12.481 sec)
# INFO:tensorflow:lr = 0.00023944 (12.481 sec)
# INFO:tensorflow:Saving checkpoints for 150000 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.26223
# INFO:tensorflow:loss = 5.07794, step = 150000 (13.770 sec)
# INFO:tensorflow:lr = 0.00024000002 (13.771 sec)
# INFO:tensorflow:global_step/sec: 7.7416
# INFO:tensorflow:loss = 5.0590715, step = 150100 (12.921 sec)
# INFO:tensorflow:lr = 0.00024055995 (12.919 sec)
# INFO:tensorflow:global_step/sec: 7.97455
# INFO:tensorflow:loss = 5.0592875, step = 150200 (12.537 sec)
# INFO:tensorflow:lr = 0.00024111997 (12.537 sec)
# INFO:tensorflow:global_step/sec: 7.94407
# INFO:tensorflow:loss = 4.9025507, step = 150300 (12.588 sec)
# INFO:tensorflow:lr = 0.00024167998 (12.587 sec)
# INFO:tensorflow:global_step/sec: 7.9756
# INFO:tensorflow:loss = 4.9730215, step = 150400 (12.540 sec)
# INFO:tensorflow:lr = 0.00024223997 (12.539 sec)
# INFO:tensorflow:global_step/sec: 8.0027
# INFO:tensorflow:loss = 4.8990846, step = 150500 (12.497 sec)
# INFO:tensorflow:lr = 0.00024279999 (12.499 sec)
# INFO:tensorflow:global_step/sec: 8.01351
# INFO:tensorflow:loss = 4.999089, step = 150600 (12.481 sec)
# INFO:tensorflow:lr = 0.00024336 (12.479 sec)
# INFO:tensorflow:global_step/sec: 7.96768
# INFO:tensorflow:loss = 4.960566, step = 150700 (12.549 sec)
# INFO:tensorflow:lr = 0.00024392002 (12.551 sec)
# INFO:tensorflow:global_step/sec: 7.95465
# INFO:tensorflow:loss = 4.939783, step = 150800 (12.571 sec)
# INFO:tensorflow:lr = 0.00024448 (12.571 sec)
# INFO:tensorflow:global_step/sec: 8.01624
# INFO:tensorflow:loss = 4.9822655, step = 150900 (12.477 sec)
# INFO:tensorflow:lr = 0.00024504002 (12.475 sec)
# INFO:tensorflow:global_step/sec: 7.96755
# INFO:tensorflow:loss = 4.986761, step = 151000 (12.550 sec)
# INFO:tensorflow:lr = 0.00024559995 (12.550 sec)
# INFO:tensorflow:global_step/sec: 7.94988
# INFO:tensorflow:loss = 4.9385962, step = 151100 (12.578 sec)
# INFO:tensorflow:lr = 0.00024615997 (12.579 sec)
# INFO:tensorflow:global_step/sec: 7.90765
# INFO:tensorflow:loss = 4.922284, step = 151200 (12.647 sec)
# INFO:tensorflow:lr = 0.00024671998 (12.646 sec)
# INFO:tensorflow:global_step/sec: 7.94864
# INFO:tensorflow:loss = 4.9752126, step = 151300 (12.582 sec)
# INFO:tensorflow:lr = 0.00024727997 (12.581 sec)
# INFO:tensorflow:global_step/sec: 7.93658
# INFO:tensorflow:loss = 5.066829, step = 151400 (12.600 sec)
# INFO:tensorflow:lr = 0.00024783998 (12.601 sec)
# INFO:tensorflow:global_step/sec: 7.99806
# INFO:tensorflow:loss = 4.908209, step = 151500 (12.500 sec)
# INFO:tensorflow:lr = 0.0002484 (12.500 sec)
# INFO:tensorflow:global_step/sec: 7.9626
# INFO:tensorflow:loss = 4.975037, step = 151600 (12.560 sec)
# INFO:tensorflow:lr = 0.00024896002 (12.561 sec)
# INFO:tensorflow:global_step/sec: 7.97286
# INFO:tensorflow:loss = 5.086237, step = 151700 (12.542 sec)
# INFO:tensorflow:lr = 0.00024952003 (12.541 sec)
# INFO:tensorflow:global_step/sec: 8.02484
# INFO:tensorflow:loss = 4.9424767, step = 151800 (12.459 sec)
# INFO:tensorflow:lr = 0.00025008002 (12.458 sec)
# INFO:tensorflow:global_step/sec: 7.81042
# INFO:tensorflow:loss = 4.9446535, step = 151900 (12.808 sec)
# INFO:tensorflow:lr = 0.00025063995 (12.807 sec)
# INFO:tensorflow:global_step/sec: 8.02379
# INFO:tensorflow:loss = 4.9144163, step = 152000 (12.461 sec)
# INFO:tensorflow:lr = 0.00025119996 (12.462 sec)
# INFO:tensorflow:global_step/sec: 8.032
# INFO:tensorflow:loss = 4.959787, step = 152100 (12.451 sec)
# INFO:tensorflow:lr = 0.00025175998 (12.451 sec)
# INFO:tensorflow:global_step/sec: 7.99342
# INFO:tensorflow:loss = 5.000474, step = 152200 (12.509 sec)
# INFO:tensorflow:lr = 0.00025232 (12.511 sec)
# INFO:tensorflow:global_step/sec: 7.96244
# INFO:tensorflow:loss = 4.854286, step = 152300 (12.560 sec)
# INFO:tensorflow:lr = 0.00025287998 (12.559 sec)
# INFO:tensorflow:global_step/sec: 7.91501
# INFO:tensorflow:loss = 5.1333036, step = 152400 (12.636 sec)
# INFO:tensorflow:lr = 0.00025344 (12.633 sec)
# INFO:tensorflow:global_step/sec: 7.9789
# INFO:tensorflow:loss = 4.941147, step = 152500 (12.529 sec)
# INFO:tensorflow:lr = 0.000254 (12.530 sec)
# INFO:tensorflow:global_step/sec: 8.01478
# INFO:tensorflow:loss = 4.9829073, step = 152600 (12.476 sec)
# INFO:tensorflow:lr = 0.00025456003 (12.477 sec)
# INFO:tensorflow:global_step/sec: 8.00168
# INFO:tensorflow:loss = 4.94443, step = 152700 (12.501 sec)
# INFO:tensorflow:lr = 0.00025512005 (12.500 sec)
# INFO:tensorflow:global_step/sec: 8.01271
# INFO:tensorflow:loss = 5.0310726, step = 152800 (12.479 sec)
# INFO:tensorflow:lr = 0.00025567994 (12.480 sec)
# INFO:tensorflow:global_step/sec: 7.97427
# INFO:tensorflow:loss = 4.8922563, step = 152900 (12.541 sec)
# INFO:tensorflow:lr = 0.00025623996 (12.539 sec)
# INFO:tensorflow:global_step/sec: 7.99996
# INFO:tensorflow:loss = 4.861654, step = 153000 (12.502 sec)
# INFO:tensorflow:lr = 0.00025679998 (12.502 sec)
# INFO:tensorflow:global_step/sec: 7.99121
# INFO:tensorflow:loss = 5.0611377, step = 153100 (12.512 sec)
# INFO:tensorflow:lr = 0.00025736 (12.513 sec)
# INFO:tensorflow:global_step/sec: 8.02391
# INFO:tensorflow:loss = 5.138193, step = 153200 (12.463 sec)
# INFO:tensorflow:lr = 0.00025792 (12.463 sec)
# INFO:tensorflow:global_step/sec: 8.0367
# INFO:tensorflow:loss = 5.0872684, step = 153300 (12.443 sec)
# INFO:tensorflow:lr = 0.00025848 (12.443 sec)
# INFO:tensorflow:global_step/sec: 8.02843
# INFO:tensorflow:loss = 4.978637, step = 153400 (12.455 sec)
# INFO:tensorflow:lr = 0.00025904 (12.455 sec)
# INFO:tensorflow:global_step/sec: 8.02441
# INFO:tensorflow:loss = 4.9554944, step = 153500 (12.462 sec)
# INFO:tensorflow:lr = 0.00025960003 (12.461 sec)
# INFO:tensorflow:global_step/sec: 7.95958
# INFO:tensorflow:loss = 4.7722588, step = 153600 (12.563 sec)
# INFO:tensorflow:lr = 0.00026015996 (12.564 sec)
# INFO:tensorflow:global_step/sec: 8.01378
# INFO:tensorflow:loss = 4.8968606, step = 153700 (12.481 sec)
# INFO:tensorflow:lr = 0.00026071997 (12.481 sec)
# INFO:tensorflow:global_step/sec: 7.9983
# INFO:tensorflow:loss = 4.920043, step = 153800 (12.503 sec)
# INFO:tensorflow:lr = 0.00026127996 (12.503 sec)
# INFO:tensorflow:global_step/sec: 8.01512
# INFO:tensorflow:loss = 4.9039884, step = 153900 (12.475 sec)
# INFO:tensorflow:lr = 0.00026183997 (12.476 sec)
# INFO:tensorflow:global_step/sec: 8.04321
# INFO:tensorflow:loss = 4.806597, step = 154000 (12.433 sec)
# INFO:tensorflow:lr = 0.0002624 (12.434 sec)
# INFO:tensorflow:global_step/sec: 7.99853
# INFO:tensorflow:loss = 4.984074, step = 154100 (12.504 sec)
# INFO:tensorflow:lr = 0.00026296 (12.503 sec)
# INFO:tensorflow:global_step/sec: 7.96776
# INFO:tensorflow:loss = 4.887099, step = 154200 (12.551 sec)
# INFO:tensorflow:lr = 0.00026352 (12.551 sec)
# INFO:tensorflow:global_step/sec: 7.94962
# INFO:tensorflow:loss = 4.8697486, step = 154300 (12.578 sec)
# INFO:tensorflow:lr = 0.00026408 (12.579 sec)
# INFO:tensorflow:global_step/sec: 7.85318
# INFO:tensorflow:loss = 4.9194536, step = 154400 (12.729 sec)
# INFO:tensorflow:lr = 0.00026464002 (12.731 sec)
# INFO:tensorflow:global_step/sec: 7.94857
# INFO:tensorflow:loss = 4.847441, step = 154500 (12.585 sec)
# INFO:tensorflow:lr = 0.00026519995 (12.583 sec)
# INFO:tensorflow:global_step/sec: 7.96035
# INFO:tensorflow:loss = 4.979674, step = 154600 (12.561 sec)
# INFO:tensorflow:lr = 0.00026575997 (12.562 sec)
# INFO:tensorflow:global_step/sec: 7.99346
# INFO:tensorflow:loss = 5.0742817, step = 154700 (12.512 sec)
# INFO:tensorflow:lr = 0.00026631996 (12.511 sec)
# INFO:tensorflow:global_step/sec: 8.00715
# INFO:tensorflow:loss = 4.826838, step = 154800 (12.489 sec)
# INFO:tensorflow:lr = 0.00026687997 (12.489 sec)
# INFO:tensorflow:global_step/sec: 7.92766
# INFO:tensorflow:loss = 4.9186416, step = 154900 (12.610 sec)
# INFO:tensorflow:lr = 0.00026744 (12.612 sec)
# INFO:tensorflow:Saving checkpoints for 155000 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.12748
# INFO:tensorflow:loss = 5.1432157, step = 155000 (14.030 sec)
# INFO:tensorflow:lr = 0.000268 (14.030 sec)
# INFO:tensorflow:global_step/sec: 7.80706
# INFO:tensorflow:loss = 5.0138173, step = 155100 (12.813 sec)
# INFO:tensorflow:lr = 0.00026856002 (12.811 sec)
# INFO:tensorflow:global_step/sec: 8.01874
# INFO:tensorflow:loss = 5.061845, step = 155200 (12.467 sec)
# INFO:tensorflow:lr = 0.00026912 (12.466 sec)
# INFO:tensorflow:global_step/sec: 8.0719
# INFO:tensorflow:loss = 4.9441032, step = 155300 (12.388 sec)
# INFO:tensorflow:lr = 0.00026968002 (12.391 sec)
# INFO:tensorflow:global_step/sec: 8.04131
# INFO:tensorflow:loss = 4.9995313, step = 155400 (12.438 sec)
# INFO:tensorflow:lr = 0.00027023995 (12.436 sec)
# INFO:tensorflow:global_step/sec: 8.01091
# INFO:tensorflow:loss = 4.942771, step = 155500 (12.484 sec)
# INFO:tensorflow:lr = 0.00027079997 (12.484 sec)
# INFO:tensorflow:global_step/sec: 8.07682
# INFO:tensorflow:loss = 4.9876604, step = 155600 (12.380 sec)
# INFO:tensorflow:lr = 0.00027135998 (12.381 sec)
# INFO:tensorflow:global_step/sec: 8.02642
# INFO:tensorflow:loss = 4.801024, step = 155700 (12.457 sec)
# INFO:tensorflow:lr = 0.00027191997 (12.456 sec)
# INFO:tensorflow:global_step/sec: 8.0664
# INFO:tensorflow:loss = 4.853264, step = 155800 (12.396 sec)
# INFO:tensorflow:lr = 0.00027247999 (12.401 sec)
# INFO:tensorflow:global_step/sec: 8.0059
# INFO:tensorflow:loss = 5.008504, step = 155900 (12.495 sec)
# INFO:tensorflow:lr = 0.00027304 (12.491 sec)
# INFO:tensorflow:global_step/sec: 8.0699
# INFO:tensorflow:loss = 4.918773, step = 156000 (12.394 sec)
# INFO:tensorflow:lr = 0.00027360002 (12.394 sec)
# INFO:tensorflow:global_step/sec: 7.99237
# INFO:tensorflow:loss = 4.985506, step = 156100 (12.508 sec)
# INFO:tensorflow:lr = 0.00027416003 (12.509 sec)
# INFO:tensorflow:global_step/sec: 8.02501
# INFO:tensorflow:loss = 4.8895783, step = 156200 (12.460 sec)
# INFO:tensorflow:lr = 0.00027472002 (12.460 sec)
# INFO:tensorflow:Saving checkpoints for 156250 into ../model/transformer_rnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.875568.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3208724be0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method TiedDense.call of <__main__.TiedDense object at 0x7f3208724be0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer_rnn/model.ckpt-156250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ------------
# unit test
# Q: 你 好
# A1: 你 好
# A2: 谢 谢
# A3: 你 也 好
#
# Q: 早 上 好
# A1: 早 上 好
# A2: 早 安
# A3: 晚 安
#
# Q: 晚 上 好
# A1: 晚 上 好
# A2: 晚 安
# A3: 早 上 好
#
# Q: 再 见
# A1: 再 见
# A2: 哈 哈
# A3: 好 的
#
# Q: 好 久 不 见
# A1: 好 久 不 见
# A2: 是 啊
# A3: 嗯 嗯
#
# Q: 想 死 你 了
# A1: 哈 哈
# A2: 我 也 是
# A3: 我 也 想 你
#
# Q: 谢 谢 你
# A1: 不 客 气
# A2: 不 用 谢
# A3: 不 谢
#
# Q: 爱 你
# A1: 爱 你
# A2: 我 也 爱 你
# A3: 我 爱 你
#
# Q: 你 好 厉 害 啊
# A1: 哈 哈
# A2: 不 厉 害
# A3: 我 也 是
#
# Q: 你 叫 什 么
# A1: 你 猜
# A2: 你 叫 什 么
# A3: 我 叫 什 么
#
# Q: 你 几 岁 了
# A1: 你 猜
# A2: 2 3
# A3: 小 女 子 年 方 二 八
#
# Q: 现 在 几 点
# A1: 八 点
# A2: 十 二 点
# A3: 1 1 点
#
# Q: 今 天 天 气 怎 么 样
# A1: 下 雨 了
# A2: 不 知 道
# A3: 今 天 下 雨
#
# Q: 我 们 现 在 在 哪 里
# A1: 好 吧
# A2: 你 在 哪
# A3: 你 在 哪 里
#
# Q: 讲 个 笑 话
# A1: 笑 话
# A2: 哈 哈
# A3: 笑 死 我 了
#
# Q: 你 会 几 种 语 言 呀
# A1: 哈 哈
# A2: 好 吧
# A3: 不 会 吧
#
# Q: 你 觉 得 我 帅 吗
# A1: 不 帅
# A2: 帅 啊
# A3: 帅 不 帅
#
# Q: 讨 厌 的 周 一
# A1: 哈 哈
# A2: 好 吧
# A3: 我 也 是
#
# Q: 好 烦 啊
# A1: 怎 么 了
# A2: 怎 么 啦
# A3: 怎 么 了 ？
#
# Q: 天 气 真 好
# A1: 是 啊
# A2: 是 的
# A3: 天 气 好
#
# Q: 今 天 好 冷
# A1: 是 啊
# A2: 是 的
# A3: 好 冷
#
# Q: 今 天 好 热
# A1: 是 啊
# A2: 是 的
# A3: 我 也 是
#
# Q: 下 雨 了
# A1: 是 啊
# A2: 是 的
# A3: 下 雨 了
#
# ...
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/query/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/query/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/key/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/key/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/value/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/value/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/output/kernel:0' shape=(512, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/attention/multihead_attention/output/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/output/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/output/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/fnn/conv1/kernel:0' shape=(300, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/fnn/conv1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/fnn/conv2/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_2/fnn/conv2/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/query/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/query/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/key/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/key/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/value/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/value/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/output/kernel:0' shape=(512, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/attention/multihead_attention/output/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/output/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/output/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/fnn/conv1/kernel:0' shape=(300, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/fnn/conv1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/fnn/conv2/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_3/fnn/conv2/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/query/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/query/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/key/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/key/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/value/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/value/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/output/kernel:0' shape=(512, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/attention/multihead_attention/output/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/output/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/output/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/fnn/conv1/kernel:0' shape=(300, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/fnn/conv1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/fnn/conv2/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_4/fnn/conv2/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/query/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/query/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/key/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/key/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/value/kernel:0' shape=(300, 512) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/value/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/output/kernel:0' shape=(512, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/attention/multihead_attention/output/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/output/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/output/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/fnn/conv1/kernel:0' shape=(300, 1200) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/fnn/conv1/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/fnn/conv2/kernel:0' shape=(1200, 300) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/layer_5/fnn/conv2/bias:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/LayerNorm/beta:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Encoder/transformer_encoder/LayerNorm/gamma:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/memory_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/kernel:0' shape=(900, 1200) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/lstm_cell/bias:0' shape=(1200,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/query_layer/kernel:0' shape=(300, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/bahdanau_attention/attention_v:0' shape=(300,) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/attention_wrapper/attention_layer/kernel:0' shape=(600, 300) dtype=float32_ref>,
#  <tf.Variable 'Decoder/decoder/tied_dense/bias:0' shape=(3927,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model/transformer_rnn/model.ckpt-250000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 250000 into ../model/transformer_rnn/model.ckpt.
# Reading ../data/train.txt
# INFO:tensorflow:loss = 4.907527, step = 250000
# INFO:tensorflow:lr = 1e-04
# INFO:tensorflow:global_step/sec: 6.46506
# INFO:tensorflow:loss = 4.8402224, step = 250100 (15.471 sec)
# INFO:tensorflow:lr = 0.00010013998 (15.471 sec)
# INFO:tensorflow:global_step/sec: 7.80074
# INFO:tensorflow:loss = 4.8190055, step = 250200 (12.820 sec)
# INFO:tensorflow:lr = 0.000100280005 (12.820 sec)
# INFO:tensorflow:global_step/sec: 7.79547
# INFO:tensorflow:loss = 4.838428, step = 250300 (12.829 sec)
# INFO:tensorflow:lr = 0.00010041998 (12.830 sec)
# INFO:tensorflow:global_step/sec: 7.66461
# INFO:tensorflow:loss = 5.046313, step = 250400 (13.047 sec)
# INFO:tensorflow:lr = 0.000100560006 (13.046 sec)
# INFO:tensorflow:global_step/sec: 7.70046
# INFO:tensorflow:loss = 4.722642, step = 250500 (12.983 sec)
# INFO:tensorflow:lr = 0.00010069999 (12.984 sec)
# INFO:tensorflow:global_step/sec: 7.74372
# INFO:tensorflow:loss = 4.868089, step = 250600 (12.917 sec)
# INFO:tensorflow:lr = 0.000100840014 (12.917 sec)
# INFO:tensorflow:global_step/sec: 7.70389
# INFO:tensorflow:loss = 4.950235, step = 250700 (12.982 sec)
# INFO:tensorflow:lr = 0.000100979996 (12.981 sec)
# INFO:tensorflow:global_step/sec: 7.77592
# INFO:tensorflow:loss = 4.829816, step = 250800 (12.859 sec)
# INFO:tensorflow:lr = 0.000101120015 (12.860 sec)
# INFO:tensorflow:global_step/sec: 7.723
# INFO:tensorflow:loss = 4.789652, step = 250900 (12.949 sec)
# INFO:tensorflow:lr = 0.00010126 (12.951 sec)
# INFO:tensorflow:global_step/sec: 7.74425
# INFO:tensorflow:loss = 4.90322, step = 251000 (12.911 sec)
# INFO:tensorflow:lr = 0.00010139998 (12.910 sec)
# INFO:tensorflow:global_step/sec: 7.79863
# INFO:tensorflow:loss = 4.787225, step = 251100 (12.823 sec)
# INFO:tensorflow:lr = 0.000101540005 (12.823 sec)
# INFO:tensorflow:global_step/sec: 7.72823
# INFO:tensorflow:loss = 4.985396, step = 251200 (12.941 sec)
# INFO:tensorflow:lr = 0.00010167999 (12.938 sec)
# INFO:tensorflow:global_step/sec: 7.73255
# INFO:tensorflow:loss = 4.8381686, step = 251300 (12.932 sec)
# INFO:tensorflow:lr = 0.000101820006 (12.933 sec)
# INFO:tensorflow:global_step/sec: 7.72422
# INFO:tensorflow:loss = 4.804066, step = 251400 (12.946 sec)
# INFO:tensorflow:lr = 0.00010195999 (12.946 sec)
# INFO:tensorflow:global_step/sec: 7.69773
# INFO:tensorflow:loss = 4.853679, step = 251500 (12.988 sec)
# INFO:tensorflow:lr = 0.00010210001 (12.992 sec)
# INFO:tensorflow:global_step/sec: 7.75975
# INFO:tensorflow:loss = 4.8137026, step = 251600 (12.890 sec)
# INFO:tensorflow:lr = 0.000102239996 (12.885 sec)
# INFO:tensorflow:global_step/sec: 7.74057
# INFO:tensorflow:loss = 5.028424, step = 251700 (12.916 sec)
# INFO:tensorflow:lr = 0.000102380014 (12.918 sec)
# INFO:tensorflow:global_step/sec: 7.72365
# INFO:tensorflow:loss = 4.9622416, step = 251800 (12.949 sec)
# INFO:tensorflow:lr = 0.000102519996 (12.948 sec)
# INFO:tensorflow:global_step/sec: 7.67262
# INFO:tensorflow:loss = 4.943933, step = 251900 (13.035 sec)
# INFO:tensorflow:lr = 0.00010265998 (13.034 sec)
# INFO:tensorflow:global_step/sec: 7.68392
# INFO:tensorflow:loss = 4.9139385, step = 252000 (13.013 sec)
# INFO:tensorflow:lr = 0.000102800004 (13.015 sec)
# INFO:tensorflow:global_step/sec: 7.76964
# INFO:tensorflow:loss = 4.8670473, step = 252100 (12.871 sec)
# INFO:tensorflow:lr = 0.00010293999 (12.871 sec)
# INFO:tensorflow:global_step/sec: 7.71888
# INFO:tensorflow:loss = 4.9296594, step = 252200 (12.954 sec)
# INFO:tensorflow:lr = 0.000103080005 (12.952 sec)
# INFO:tensorflow:global_step/sec: 7.73465
# INFO:tensorflow:loss = 4.889816, step = 252300 (12.931 sec)
# INFO:tensorflow:lr = 0.00010321999 (12.931 sec)
# INFO:tensorflow:global_step/sec: 7.79478
# INFO:tensorflow:loss = 4.8727694, step = 252400 (12.829 sec)
# INFO:tensorflow:lr = 0.00010336001 (12.829 sec)
# INFO:tensorflow:global_step/sec: 7.69361
# INFO:tensorflow:loss = 4.868938, step = 252500 (12.998 sec)
# INFO:tensorflow:lr = 0.000103499995 (12.998 sec)
# INFO:tensorflow:global_step/sec: 7.66201
# INFO:tensorflow:loss = 4.9304395, step = 252600 (13.049 sec)
# INFO:tensorflow:lr = 0.00010364002 (13.051 sec)
# INFO:tensorflow:global_step/sec: 7.77772
# INFO:tensorflow:loss = 4.775693, step = 252700 (12.860 sec)
# INFO:tensorflow:lr = 0.000103779996 (12.857 sec)
# INFO:tensorflow:global_step/sec: 7.63913
# INFO:tensorflow:loss = 5.049201, step = 252800 (13.088 sec)
# INFO:tensorflow:lr = 0.00010391998 (13.088 sec)
# INFO:tensorflow:global_step/sec: 7.67045
# INFO:tensorflow:loss = 4.8931465, step = 252900 (13.039 sec)
# INFO:tensorflow:lr = 0.000104060004 (13.039 sec)
# INFO:tensorflow:global_step/sec: 7.71999
# INFO:tensorflow:loss = 5.030292, step = 253000 (12.950 sec)
# INFO:tensorflow:lr = 0.000104199986 (12.951 sec)
# INFO:tensorflow:global_step/sec: 7.67837
# INFO:tensorflow:loss = 4.934297, step = 253100 (13.026 sec)
# INFO:tensorflow:lr = 0.00010434001 (13.027 sec)
# INFO:tensorflow:global_step/sec: 7.69626
# INFO:tensorflow:loss = 4.958365, step = 253200 (12.993 sec)
# INFO:tensorflow:lr = 0.00010447999 (12.993 sec)
# INFO:tensorflow:global_step/sec: 7.71452
# INFO:tensorflow:loss = 4.9171524, step = 253300 (12.959 sec)
# INFO:tensorflow:lr = 0.00010462001 (12.959 sec)
# INFO:tensorflow:global_step/sec: 7.70419
# INFO:tensorflow:loss = 4.9700584, step = 253400 (12.982 sec)
# INFO:tensorflow:lr = 0.000104759994 (12.983 sec)
# INFO:tensorflow:global_step/sec: 7.76335
# INFO:tensorflow:loss = 5.0563893, step = 253500 (12.884 sec)
# INFO:tensorflow:lr = 0.00010489998 (12.882 sec)
# INFO:tensorflow:global_step/sec: 7.74
# INFO:tensorflow:loss = 4.918072, step = 253600 (12.917 sec)
# INFO:tensorflow:lr = 0.00010504 (12.917 sec)
# INFO:tensorflow:global_step/sec: 7.75603
# INFO:tensorflow:loss = 4.9869184, step = 253700 (12.895 sec)
# INFO:tensorflow:lr = 0.00010517998 (12.895 sec)
# INFO:tensorflow:global_step/sec: 7.66638
# INFO:tensorflow:loss = 4.8983183, step = 253800 (13.041 sec)
# INFO:tensorflow:lr = 0.00010532 (13.042 sec)
# INFO:tensorflow:global_step/sec: 7.63871
# INFO:tensorflow:loss = 4.895661, step = 253900 (13.095 sec)
# INFO:tensorflow:lr = 0.000105459985 (13.094 sec)
# INFO:tensorflow:global_step/sec: 7.68202
# INFO:tensorflow:loss = 5.005845, step = 254000 (13.018 sec)
# INFO:tensorflow:lr = 0.00010560001 (13.019 sec)
# INFO:tensorflow:global_step/sec: 7.78179
# INFO:tensorflow:loss = 4.9965997, step = 254100 (12.850 sec)
# INFO:tensorflow:lr = 0.00010573999 (12.849 sec)
# INFO:tensorflow:global_step/sec: 7.77492
# INFO:tensorflow:loss = 4.9918127, step = 254200 (12.859 sec)
# INFO:tensorflow:lr = 0.00010588001 (12.863 sec)
# INFO:tensorflow:global_step/sec: 7.72743
# INFO:tensorflow:loss = 4.978217, step = 254300 (12.944 sec)
# INFO:tensorflow:lr = 0.000106019994 (12.941 sec)
# INFO:tensorflow:global_step/sec: 7.72697
# INFO:tensorflow:loss = 4.9942055, step = 254400 (12.941 sec)
# INFO:tensorflow:lr = 0.000106159976 (12.941 sec)
# INFO:tensorflow:global_step/sec: 7.76446
# INFO:tensorflow:loss = 5.0093946, step = 254500 (12.876 sec)
# INFO:tensorflow:lr = 0.0001063 (12.876 sec)
# INFO:tensorflow:global_step/sec: 7.72936
# INFO:tensorflow:loss = 4.865727, step = 254600 (12.941 sec)
# INFO:tensorflow:lr = 0.000106439984 (12.941 sec)
# INFO:tensorflow:global_step/sec: 7.74149
# INFO:tensorflow:loss = 5.0529, step = 254700 (12.917 sec)
# INFO:tensorflow:lr = 0.00010658 (12.918 sec)
# INFO:tensorflow:global_step/sec: 7.70415
# INFO:tensorflow:loss = 5.086498, step = 254800 (12.977 sec)
# INFO:tensorflow:lr = 0.000106719985 (12.977 sec)
