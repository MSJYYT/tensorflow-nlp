# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/spoken_language_understanding/atis/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from tensorflow_addons.optimizers.cyclical_learning_rate import Triangular2CyclicalLearningRate
from sklearn.metrics import classification_report, f1_score, accuracy_score

import tensorflow as tf
import pprint
import logging
import time
import numpy as np

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.3.0
# WARNING:tensorflow:From <ipython-input-3-27b53cc52b5d>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(vocab_path):
  word2idx = {}
  with open(vocab_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
def data_generator(f_path, params):
  print('Reading', f_path)
  with open(f_path) as f:
    for line in f:
      line = line.rstrip()
      text, slot_intent = line.split('\t')
      words = text.split()[1:-1]
      slot_intent = slot_intent.split()
      slots, intent = slot_intent[1:-1], slot_intent[-1]
      assert len(words) == len(slots)
      
      words = [params['word2idx'].get(w, len(params['word2idx'])) for w in words]
      intent = params['intent2idx'].get(intent, len(params['intent2idx']))
      slots = [params['slot2idx'].get(s, len(params['slot2idx'])) for s in slots]
      
      yield (words, (intent, slots))

# %%
def dataset(is_training, params):
  _shapes = ([None], ((), [None]))
  _types = (tf.int32, (tf.int32, tf.int32))
  _pads = (0, (-1, 0))
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['num_samples'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
def get_timing_signal_1d(length,
                         channels,
                         min_timescale=1.0,
                         max_timescale=1.0e4,
                         start_index=0):
  to_float = lambda x: tf.cast(x, tf.float32)
  position = to_float(tf.range(length) + start_index)
  num_timescales = channels // 2
  log_timescale_increment = (
      tf.math.log(float(max_timescale) / float(min_timescale)) /
      tf.maximum(to_float(num_timescales) - 1, 1))
  inv_timescales = min_timescale * tf.exp(
      to_float(tf.range(num_timescales)) * -log_timescale_increment)
  scaled_time = tf.expand_dims(position, 1) * tf.expand_dims(inv_timescales, 0)
  signal = tf.concat([tf.sin(scaled_time), tf.cos(scaled_time)], axis=1)
  signal = tf.pad(signal, [[0, 0], [0, tf.compat.v1.mod(channels, 2)]])
  signal = tf.reshape(signal, [1, length, channels])
  return signal

# %%
class LayerNorm(tf.keras.layers.Layer):
  def __init__(self, params):
    super().__init__()
    self._epsilon = params['epsilon']
    self._hidden_units = params['global_units']
  
  def build(self, input_shape):
    self.scale = self.add_weight(name='scale',
                                 shape=[self._hidden_units],
                                 initializer=tf.ones_initializer(),
                                 trainable=True)
    self.bias = self.add_weight(name='bias',
                                shape=[self._hidden_units],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    mean, variance = tf.nn.moments(inputs, [-1], keepdims=True)
    norm_x = (inputs - mean) * tf.math.rsqrt(variance + self._epsilon)
    return norm_x * self.scale + self.bias
  
  def compute_output_shape(self, input_shape):
    return input_shape


class EncoderBlock(tf.keras.Model):
  def __init__(self, SubModel, params, name):
    super().__init__(name = name)
    self.layer_norm = LayerNorm(params)
    self.sub_model = SubModel(params)
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
  
  def call(self, inputs, training):
    inputs, masks = inputs
    x = self.layer_norm(inputs)
    x = self.sub_model((x, masks), training=training)
    x = self.dropout(x, training=training)
    x += inputs
    return x


class MultiheadSelfAttention(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.qkv_linear = tf.keras.layers.Dense(3*params['hidden_units'], name='qkv_linear')
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(params['global_units'], params['activation'], name='out_linear')
    self.num_heads = params['num_heads']
    self.is_bidirectional = params['is_bidirectional']
  
  def call(self, inputs, training):
    x, masks = inputs
    batch_sz = tf.shape(x)[0]
    timesteps = tf.shape(x)[1]
    
    x_left = tf.concat((tf.zeros((batch_sz, 1, params['global_units'])), x[:, :-1, :]), axis=1)
    x_right = tf.concat((x[:, 1:, :], tf.zeros((batch_sz, 1, params['global_units']))), axis=1)
    x = tf.concat((x_left[:, :, :100], x[:, :, 100:200], x_right[:, :, 200:]), axis=-1)

    q_k_v = self.qkv_linear(x)
    q, k, v = tf.split(q_k_v, 3, axis=-1)
    
    if self.num_heads > 1:
      q = tf.concat(tf.split(q, self.num_heads, axis=2), axis=0)                        
      k = tf.concat(tf.split(k, self.num_heads, axis=2), axis=0)                        
      v = tf.concat(tf.split(v, self.num_heads, axis=2), axis=0)
    
    align = tf.matmul(q, k, transpose_b=True)
    align *= tf.math.rsqrt(tf.cast(k.shape[-1], tf.float32))
    
    if (masks is not None) or (not self.is_bidirectional):
      paddings = tf.fill(tf.shape(align), float('-inf'))
    
    if masks is not None:
      c_masks = tf.tile(masks, [params['num_heads'], 1])
      c_masks = tf.tile(tf.expand_dims(c_masks, 1), [1, timesteps, 1])
      align = tf.where(tf.equal(c_masks, 0), paddings, align)
    
    if not self.is_bidirectional:
      lower_tri = tf.ones((timesteps, timesteps))                                       
      lower_tri = tf.linalg.LinearOperatorLowerTriangular(lower_tri).to_dense()      
      t_masks = tf.tile(tf.expand_dims(lower_tri, 0), [tf.shape(align)[0], 1, 1])     
      align = tf.where(tf.equal(t_masks, 0), paddings, align)
    
    align = tf.nn.softmax(align)
    align = self.dropout(align, training=training)
    
    if masks is not None:
      q_masks = tf.tile(masks, [params['num_heads'], 1])
      q_masks = tf.tile(tf.expand_dims(q_masks, 2), [1, 1, timesteps])
      align *= tf.cast(q_masks, tf.float32)
    
    x = tf.matmul(align, v)
    if self.num_heads > 1:
      x = tf.concat(tf.split(x, self.num_heads, axis=0), axis=2)
    x = self.out_linear(x)
    
    return x
  

class PointwiseFFN(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.dense_1 = tf.keras.layers.Dense(params['multiplier']*params['global_units'], params['activation'], name='fc')
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.dense_2 = tf.keras.layers.Dense(params['global_units'], name='linear')
  
  def call(self, inputs, training):
    x, masks = inputs
    return self.dense_2(self.dropout(self.dense_1(x), training=training))

# %%
class Model(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    self.embedding = tf.Variable(np.load(params['vocab_path']),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
    self.input_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.blocks = []
    for i in range(params['num_layers']):
      self.blocks.append(EncoderBlock(
          MultiheadSelfAttention, params, name='layer{}.1'.format(i+1)))
      self.blocks.append(EncoderBlock(
          PointwiseFFN, params, name='layer{}.2'.format(i+1)))
    
    self.intent_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.fc_intent = tf.keras.layers.Dense(params['global_units'], params['activation'], name='fc_intent')
    self.out_linear_intent = tf.keras.layers.Dense(params['intent_size'], name='output_intent')
    self.out_linear_slot = tf.keras.layers.Dense(params['slot_size'], name='output_slot')
    
  
  def call(self, inputs, training):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    masks = tf.sign(inputs)
    
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    if params['is_embedding_scaled']:
      x *= tf.sqrt(tf.cast(params['global_units'], tf.float32))
    x += get_timing_signal_1d(tf.shape(x)[1], params['global_units'])
    x = self.input_dropout(x, training=training)
    
    for block in self.blocks:
      x = block((x, masks), training=training)
    
    x_intent = tf.reduce_max(x, 1)
    x_intent = self.intent_dropout(x_intent, training=training)
    x_intent = self.out_linear_intent(self.fc_intent(x_intent))
    x_slot = self.out_linear_slot(x)
    return (x_intent, x_slot)

# %%
params = {
  'train_path': '../data/atis.train.w-intent.iob',
  'test_path': '../data/atis.test.w-intent.iob',
  'word_path': '../vocab/word.txt',
  'vocab_path': '../vocab/word.npy',
  'intent_path': '../vocab/intent.txt',
  'slot_path': '../vocab/slot.txt',
  'batch_size': 16,
  'num_samples': 4978,
  'num_layers': 2,
  'global_units': 300,
  'hidden_units': 512,
  'activation': tf.nn.elu,
  'num_heads': 8,
  'multiplier': 2,
  'dropout_rate': .1,
  'epsilon': 1e-6,
  'is_bidirectional': True,
  'is_embedding_scaled': False,
  'clip_norm': 5.,
}

# %%
params['word2idx'] = get_vocab(params['word_path'])
params['intent2idx'] = get_vocab(params['intent_path'])
params['slot2idx'] = get_vocab(params['slot_path'])

params['word_size'] = len(params['word2idx']) + 1
params['intent_size'] = len(params['intent2idx']) + 1
params['slot_size'] = len(params['slot2idx']) + 1

# %%
model = Model(params)
model.build(input_shape=(None, None))
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = Triangular2CyclicalLearningRate(
  initial_learning_rate = 1e-4,
  maximal_learning_rate = 8e-4,
  step_size = 8 * params['num_samples'] // params['batch_size'],
)
optim = tf.optimizers.Adam(1e-4)
global_step = 0

slot_best_f1 = .0
intent_acc_with_that = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

for n_epoch in range(1, 64+1):
  # TRAINING
  for (words, (intent, slots)) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      y_intent, y_slots = model(words, training=True)
      loss_intent = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(intent, len(params['intent2idx'])+1),
        logits = y_intent,
        label_smoothing = .2)
      # weight of 'O' is set to be small
      weights = tf.cast(tf.sign(slots), tf.float32)
      padding = tf.constant(1e-2, tf.float32, weights.shape)
      weights = tf.where(tf.equal(weights, 0.), padding, weights)

      loss_slots = tf.compat.v1.losses.softmax_cross_entropy(
        onehot_labels = tf.one_hot(slots, len(params['slot2idx'])+1),
        logits = y_slots,
        weights = tf.cast(weights, tf.float32),
        label_smoothing = .2)
      # joint loss
      loss = loss_intent + loss_slots
    
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))

    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Loss_intent: {:.4f} | Loss_slots: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), loss_intent.numpy().item(), loss_slots.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
    
  # EVALUATION
  intent_true = []
  intent_pred = []
  slot_true = []
  slot_pred = []

  for (words, (intent, slots)) in dataset(is_training=False, params=params):
    y_intent, y_slots = model(words, training=False)
    y_intent = tf.argmax(y_intent, -1)
    y_slots = tf.argmax(y_slots, -1)
    
    intent_true += intent.numpy().flatten().tolist()
    intent_pred += y_intent.numpy().flatten().tolist()
    slot_true += slots.numpy().flatten().tolist()
    slot_pred += y_slots.numpy().flatten().tolist()
    
  f1_slots = f1_score(y_true = slot_true,
                      y_pred = slot_pred,
                      labels = list(params['slot2idx'].values()),
                      sample_weight = np.sign(slot_true),
                      average='micro',)
  
  acc_intent = accuracy_score(intent_true, intent_pred)

  logger.info("Slot F1: {:.3f}, Intent Acc: {:.3f}".format(f1_slots, acc_intent))

  if n_epoch != 1 and n_epoch % 8 == 0:
    logger.info('\n'+classification_report(y_true = intent_true,
                                          y_pred = intent_pred,
                                          labels = list(params['intent2idx'].values()),
                                          target_names = list(params['intent2idx'].keys()),
                                          digits=3))
    logger.info('\n'+classification_report(y_true = slot_true,
                                          y_pred = slot_pred,
                                          labels = list(params['slot2idx'].values()),
                                          target_names = list(params['slot2idx'].keys()),
                                          sample_weight = np.sign(slot_true),
                                          digits=3))
  
  if f1_slots > slot_best_f1:
    slot_best_f1 = f1_slots
    intent_acc_with_that = acc_intent
    # you can save model here
  logger.info("Best Slot F1: {:.3f}, Intent Acc: {:.3f}".format(slot_best_f1, intent_acc_with_that))
# Out:
# [('layer1.1/layer_norm/scale:0', TensorShape([300])),
#  ('layer1.1/layer_norm/bias:0', TensorShape([300])),
#  ('layer1.1/multihead_self_attention/qkv_linear/kernel:0',
#   TensorShape([300, 1536])),
#  ('layer1.1/multihead_self_attention/qkv_linear/bias:0', TensorShape([1536])),
#  ('layer1.1/multihead_self_attention/out_linear/kernel:0',
#   TensorShape([512, 300])),
#  ('layer1.1/multihead_self_attention/out_linear/bias:0', TensorShape([300])),
#  ('layer1.2/layer_norm_1/scale:0', TensorShape([300])),
#  ('layer1.2/layer_norm_1/bias:0', TensorShape([300])),
#  ('layer1.2/pointwise_ffn/fc/kernel:0', TensorShape([300, 600])),
#  ('layer1.2/pointwise_ffn/fc/bias:0', TensorShape([600])),
#  ('layer1.2/pointwise_ffn/linear/kernel:0', TensorShape([600, 300])),
#  ('layer1.2/pointwise_ffn/linear/bias:0', TensorShape([300])),
#  ('layer2.1/layer_norm_2/scale:0', TensorShape([300])),
#  ('layer2.1/layer_norm_2/bias:0', TensorShape([300])),
#  ('layer2.1/multihead_self_attention_1/qkv_linear/kernel:0',
#   TensorShape([300, 1536])),
#  ('layer2.1/multihead_self_attention_1/qkv_linear/bias:0', TensorShape([1536])),
#  ('layer2.1/multihead_self_attention_1/out_linear/kernel:0',
#   TensorShape([512, 300])),
#  ('layer2.1/multihead_self_attention_1/out_linear/bias:0', TensorShape([300])),
#  ('layer2.2/layer_norm_3/scale:0', TensorShape([300])),
#  ('layer2.2/layer_norm_3/bias:0', TensorShape([300])),
#  ('layer2.2/pointwise_ffn_1/fc/kernel:0', TensorShape([300, 600])),
#  ('layer2.2/pointwise_ffn_1/fc/bias:0', TensorShape([600])),
#  ('layer2.2/pointwise_ffn_1/linear/kernel:0', TensorShape([600, 300])),
#  ('layer2.2/pointwise_ffn_1/linear/bias:0', TensorShape([300])),
#  ('fc_intent/kernel:0', TensorShape([300, 300])),
#  ('fc_intent/bias:0', TensorShape([300])),
#  ('output_intent/kernel:0', TensorShape([300, 23])),
#  ('output_intent/bias:0', TensorShape([23])),
#  ('output_slot/kernel:0', TensorShape([300, 122])),
#  ('output_slot/bias:0', TensorShape([122])),
#  ('pretrained_embedding:0', TensorShape([750, 300]))]
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 0 | Loss: 6.7942 | Loss_intent: 5.3442 | Loss_slots: 1.4500 | Spent: 3.1 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 2.8167 | Loss_intent: 2.0697 | Loss_slots: 0.7471 | Spent: 3.1 secs | LR: 0.000114
# INFO:tensorflow:Step 100 | Loss: 2.3236 | Loss_intent: 1.6149 | Loss_slots: 0.7088 | Spent: 3.1 secs | LR: 0.000128
# INFO:tensorflow:Step 150 | Loss: 2.5554 | Loss_intent: 1.9416 | Loss_slots: 0.6138 | Spent: 3.0 secs | LR: 0.000142
# INFO:tensorflow:Step 200 | Loss: 2.3503 | Loss_intent: 1.9699 | Loss_slots: 0.3803 | Spent: 3.3 secs | LR: 0.000156
# INFO:tensorflow:Step 250 | Loss: 1.8852 | Loss_intent: 1.2304 | Loss_slots: 0.6548 | Spent: 3.3 secs | LR: 0.000170
# INFO:tensorflow:Step 300 | Loss: 1.9828 | Loss_intent: 1.3491 | Loss_slots: 0.6338 | Spent: 3.0 secs | LR: 0.000184
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.722, Intent Acc: 0.868
# INFO:tensorflow:Best Slot F1: 0.722, Intent Acc: 0.868
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 350 | Loss: 2.1460 | Loss_intent: 1.7200 | Loss_slots: 0.4259 | Spent: 5.6 secs | LR: 0.000198
# INFO:tensorflow:Step 400 | Loss: 1.9568 | Loss_intent: 1.3051 | Loss_slots: 0.6517 | Spent: 3.1 secs | LR: 0.000212
# INFO:tensorflow:Step 450 | Loss: 1.7461 | Loss_intent: 1.1877 | Loss_slots: 0.5584 | Spent: 3.1 secs | LR: 0.000227
# INFO:tensorflow:Step 500 | Loss: 1.8926 | Loss_intent: 1.3885 | Loss_slots: 0.5040 | Spent: 3.0 secs | LR: 0.000241
# INFO:tensorflow:Step 550 | Loss: 2.0148 | Loss_intent: 1.5579 | Loss_slots: 0.4569 | Spent: 3.1 secs | LR: 0.000255
# INFO:tensorflow:Step 600 | Loss: 1.5763 | Loss_intent: 1.1837 | Loss_slots: 0.3927 | Spent: 3.0 secs | LR: 0.000269
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.813, Intent Acc: 0.890
# INFO:tensorflow:Best Slot F1: 0.813, Intent Acc: 0.890
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 650 | Loss: 1.7329 | Loss_intent: 1.3186 | Loss_slots: 0.4143 | Spent: 5.6 secs | LR: 0.000283
# INFO:tensorflow:Step 700 | Loss: 1.7099 | Loss_intent: 1.3124 | Loss_slots: 0.3975 | Spent: 3.1 secs | LR: 0.000297
# INFO:tensorflow:Step 750 | Loss: 1.6616 | Loss_intent: 1.1572 | Loss_slots: 0.5045 | Spent: 3.0 secs | LR: 0.000311
# INFO:tensorflow:Step 800 | Loss: 1.9660 | Loss_intent: 1.5472 | Loss_slots: 0.4188 | Spent: 3.2 secs | LR: 0.000325
# INFO:tensorflow:Step 850 | Loss: 1.7680 | Loss_intent: 1.3066 | Loss_slots: 0.4614 | Spent: 2.9 secs | LR: 0.000339
# INFO:tensorflow:Step 900 | Loss: 1.8689 | Loss_intent: 1.3463 | Loss_slots: 0.5226 | Spent: 3.0 secs | LR: 0.000353
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.863, Intent Acc: 0.935
# INFO:tensorflow:Best Slot F1: 0.863, Intent Acc: 0.935
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 950 | Loss: 1.6288 | Loss_intent: 1.1628 | Loss_slots: 0.4661 | Spent: 5.3 secs | LR: 0.000367
# INFO:tensorflow:Step 1000 | Loss: 1.5902 | Loss_intent: 1.1643 | Loss_slots: 0.4259 | Spent: 2.9 secs | LR: 0.000381
# INFO:tensorflow:Step 1050 | Loss: 1.7246 | Loss_intent: 1.2568 | Loss_slots: 0.4678 | Spent: 3.0 secs | LR: 0.000395
# INFO:tensorflow:Step 1100 | Loss: 1.5164 | Loss_intent: 1.2861 | Loss_slots: 0.2303 | Spent: 3.0 secs | LR: 0.000409
# INFO:tensorflow:Step 1150 | Loss: 1.7167 | Loss_intent: 1.2194 | Loss_slots: 0.4973 | Spent: 3.1 secs | LR: 0.000423
# INFO:tensorflow:Step 1200 | Loss: 1.6529 | Loss_intent: 1.1792 | Loss_slots: 0.4737 | Spent: 3.2 secs | LR: 0.000437
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.872, Intent Acc: 0.952
# INFO:tensorflow:Best Slot F1: 0.872, Intent Acc: 0.952
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1250 | Loss: 1.6903 | Loss_intent: 1.2010 | Loss_slots: 0.4893 | Spent: 5.3 secs | LR: 0.000452
# INFO:tensorflow:Step 1300 | Loss: 1.6661 | Loss_intent: 1.1374 | Loss_slots: 0.5287 | Spent: 3.2 secs | LR: 0.000466
# INFO:tensorflow:Step 1350 | Loss: 1.5729 | Loss_intent: 1.1597 | Loss_slots: 0.4132 | Spent: 3.4 secs | LR: 0.000480
# INFO:tensorflow:Step 1400 | Loss: 1.5974 | Loss_intent: 1.1188 | Loss_slots: 0.4786 | Spent: 3.1 secs | LR: 0.000494
# INFO:tensorflow:Step 1450 | Loss: 1.5595 | Loss_intent: 1.1547 | Loss_slots: 0.4048 | Spent: 3.1 secs | LR: 0.000508
# INFO:tensorflow:Step 1500 | Loss: 1.5851 | Loss_intent: 1.1052 | Loss_slots: 0.4799 | Spent: 3.0 secs | LR: 0.000522
# INFO:tensorflow:Step 1550 | Loss: 1.7294 | Loss_intent: 1.3047 | Loss_slots: 0.4247 | Spent: 3.0 secs | LR: 0.000536
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.876, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.876, Intent Acc: 0.974
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1600 | Loss: 1.6283 | Loss_intent: 1.1903 | Loss_slots: 0.4381 | Spent: 5.6 secs | LR: 0.000550
# INFO:tensorflow:Step 1650 | Loss: 1.6037 | Loss_intent: 1.1503 | Loss_slots: 0.4534 | Spent: 3.0 secs | LR: 0.000564
# INFO:tensorflow:Step 1700 | Loss: 1.5069 | Loss_intent: 1.1917 | Loss_slots: 0.3152 | Spent: 3.0 secs | LR: 0.000578
# INFO:tensorflow:Step 1750 | Loss: 1.5958 | Loss_intent: 1.1496 | Loss_slots: 0.4462 | Spent: 3.0 secs | LR: 0.000592
# INFO:tensorflow:Step 1800 | Loss: 1.5187 | Loss_intent: 1.2276 | Loss_slots: 0.2912 | Spent: 3.1 secs | LR: 0.000606
# INFO:tensorflow:Step 1850 | Loss: 1.5361 | Loss_intent: 1.2026 | Loss_slots: 0.3334 | Spent: 3.4 secs | LR: 0.000620
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.902, Intent Acc: 0.964
# INFO:tensorflow:Best Slot F1: 0.902, Intent Acc: 0.964
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 1900 | Loss: 1.5236 | Loss_intent: 1.1508 | Loss_slots: 0.3728 | Spent: 5.4 secs | LR: 0.000634
# INFO:tensorflow:Step 1950 | Loss: 1.5461 | Loss_intent: 1.1686 | Loss_slots: 0.3774 | Spent: 3.4 secs | LR: 0.000648
# INFO:tensorflow:Step 2000 | Loss: 1.4994 | Loss_intent: 1.2804 | Loss_slots: 0.2190 | Spent: 3.2 secs | LR: 0.000662
# INFO:tensorflow:Step 2050 | Loss: 1.6124 | Loss_intent: 1.1649 | Loss_slots: 0.4475 | Spent: 2.9 secs | LR: 0.000677
# INFO:tensorflow:Step 2100 | Loss: 1.4566 | Loss_intent: 1.0999 | Loss_slots: 0.3568 | Spent: 3.0 secs | LR: 0.000691
# INFO:tensorflow:Step 2150 | Loss: 1.4924 | Loss_intent: 1.1414 | Loss_slots: 0.3511 | Spent: 3.1 secs | LR: 0.000705
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.914, Intent Acc: 0.968
# INFO:tensorflow:Best Slot F1: 0.914, Intent Acc: 0.968
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2200 | Loss: 1.5376 | Loss_intent: 1.0986 | Loss_slots: 0.4390 | Spent: 5.6 secs | LR: 0.000719
# INFO:tensorflow:Step 2250 | Loss: 1.5112 | Loss_intent: 1.1190 | Loss_slots: 0.3922 | Spent: 3.2 secs | LR: 0.000733
# INFO:tensorflow:Step 2300 | Loss: 1.5592 | Loss_intent: 1.1728 | Loss_slots: 0.3864 | Spent: 3.2 secs | LR: 0.000747
# INFO:tensorflow:Step 2350 | Loss: 1.6014 | Loss_intent: 1.1591 | Loss_slots: 0.4423 | Spent: 3.1 secs | LR: 0.000761
# INFO:tensorflow:Step 2400 | Loss: 1.5186 | Loss_intent: 1.1468 | Loss_slots: 0.3718 | Spent: 3.0 secs | LR: 0.000775
# INFO:tensorflow:Step 2450 | Loss: 1.8164 | Loss_intent: 1.2472 | Loss_slots: 0.5692 | Spent: 3.1 secs | LR: 0.000789
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.922, Intent Acc: 0.965
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.994     0.978     0.986       632
#                             atis_airfare      0.941     1.000     0.970        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      0.943     1.000     0.971        33
#                            atis_aircraft      0.818     1.000     0.900         9
#                         atis_flight_time      0.500     1.000     0.667         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.875     0.583     0.700        12
#                             atis_airport      0.944     0.944     0.944        18
#                            atis_distance      1.000     0.700     0.824        10
#                                atis_city      0.286     0.667     0.400         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      0.833     0.833     0.833         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.965     0.971     0.968       888
#                                macro avg      0.610     0.668     0.624       888
#                             weighted avg      0.975     0.971     0.971       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.973     0.992     0.982     716.0
#          B-fromloc.city_name      0.959     0.996     0.977     704.0
#            I-toloc.city_name      0.938     0.966     0.952     265.0
#       B-depart_date.day_name      0.963     0.991     0.977     212.0
#               B-airline_name      0.953     1.000     0.976     101.0
#          I-fromloc.city_name      0.916     0.989     0.951     177.0
#  B-depart_time.period_of_day      0.942     0.869     0.904     130.0
#               I-airline_name      0.928     0.985     0.955      65.0
#     B-depart_date.day_number      0.914     0.964     0.938      55.0
#     B-depart_date.month_name      0.902     0.982     0.940      56.0
#           B-depart_time.time      0.824     0.982     0.896      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.958     0.958     0.958      24.0
#  B-depart_time.time_relative      0.969     0.954     0.961      65.0
#           I-depart_time.time      0.833     0.962     0.893      52.0
#          B-stoploc.city_name      1.000     0.900     0.947      20.0
#                  B-city_name      0.850     0.596     0.701      57.0
#                 B-class_type      0.889     1.000     0.941      24.0
#           B-arrive_time.time      0.914     0.941     0.928      34.0
#  B-arrive_time.time_relative      0.824     0.903     0.862      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      0.955     1.000     0.977      21.0
#           I-arrive_time.time      0.941     0.914     0.928      35.0
#               B-airline_code      0.970     0.941     0.955      34.0
#     I-depart_date.day_number      1.000     1.000     1.000      15.0
#       I-fromloc.airport_name      0.371     0.867     0.520      15.0
#       B-fromloc.airport_name      0.208     0.417     0.278      12.0
#       B-arrive_date.day_name      0.667     0.545     0.600      11.0
#           B-toloc.state_code      1.000     1.000     1.000      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.379     1.000     0.550      11.0
#  B-depart_date.date_relative      0.810     1.000     0.895      17.0
#           B-toloc.state_name      0.958     0.821     0.885      28.0
#            B-fare_basis_code      0.944     1.000     0.971      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.625     0.833     0.714       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.000     0.000     0.000      29.0
#                B-fare_amount      0.000     0.000     0.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      0.833     0.500     0.625      30.0
#         I-toloc.airport_name      0.667     0.667     0.667       3.0
#             B-transport_type      0.909     1.000     0.952      10.0
#     B-arrive_date.month_name      0.000     0.000     0.000       6.0
#     B-arrive_date.day_number      0.500     0.167     0.250       6.0
#          I-stoploc.city_name      0.000     0.000     0.000      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     1.000     1.000      23.0
#     B-depart_time.period_mod      0.500     0.400     0.444       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     0.333     0.500       3.0
#         B-fromloc.state_name      0.889     0.941     0.914      17.0
#               B-airport_name      0.000     0.000     0.000      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.727     0.842      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.800     0.444     0.571       9.0
#     B-depart_time.start_time      0.500     0.333     0.400       3.0
#       B-depart_time.end_time      0.286     0.667     0.400       3.0
#           B-depart_date.year      0.000     0.000     0.000       3.0
#             I-transport_type      0.000     0.000     0.000       1.0
#           B-restriction_code      1.000     0.750     0.857       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.500     0.667       4.0
#       B-arrive_time.end_time      1.000     0.375     0.545       8.0
#       I-arrive_time.end_time      0.800     0.500     0.615       8.0
#       I-depart_time.end_time      0.286     0.667     0.400       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      0.833     1.000     0.909       5.0
#           I-restriction_code      0.375     1.000     0.545       3.0
#     I-depart_time.start_time      0.000     0.000     0.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      0.000     0.000     0.000       2.0
#                 I-flight_mod      0.000     0.000     0.000       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.500     0.333     0.400       3.0
#         I-fromloc.state_name      0.000     0.000     0.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      0.000     0.000     0.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      0.000     0.000     0.000       1.0
#                   B-day_name      0.000     0.000     0.000       2.0
#              B-period_of_day      0.000     0.000     0.000       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      0.000     0.000     0.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.000     0.000     0.000       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.922     0.923     0.922    3657.0
#                    macro avg      0.511     0.500     0.493    3657.0
#                 weighted avg      0.908     0.923     0.912    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.922, Intent Acc: 0.965
# Reading ../data/atis.train.w-intent.iob
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:tensorflow:Step 2500 | Loss: 1.4113 | Loss_intent: 1.1038 | Loss_slots: 0.3075 | Spent: 5.7 secs | LR: 0.000797
# INFO:tensorflow:Step 2550 | Loss: 1.5920 | Loss_intent: 1.0999 | Loss_slots: 0.4920 | Spent: 3.0 secs | LR: 0.000783
# INFO:tensorflow:Step 2600 | Loss: 1.5342 | Loss_intent: 1.1589 | Loss_slots: 0.3753 | Spent: 3.0 secs | LR: 0.000769
# INFO:tensorflow:Step 2650 | Loss: 1.5055 | Loss_intent: 1.1447 | Loss_slots: 0.3608 | Spent: 3.0 secs | LR: 0.000755
# INFO:tensorflow:Step 2700 | Loss: 1.4146 | Loss_intent: 1.0957 | Loss_slots: 0.3189 | Spent: 2.9 secs | LR: 0.000741
# INFO:tensorflow:Step 2750 | Loss: 1.4632 | Loss_intent: 1.1117 | Loss_slots: 0.3515 | Spent: 3.0 secs | LR: 0.000727
# INFO:tensorflow:Step 2800 | Loss: 1.5773 | Loss_intent: 1.1003 | Loss_slots: 0.4770 | Spent: 3.1 secs | LR: 0.000713
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.917, Intent Acc: 0.969
# INFO:tensorflow:Best Slot F1: 0.922, Intent Acc: 0.965
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 2850 | Loss: 1.4644 | Loss_intent: 1.1083 | Loss_slots: 0.3561 | Spent: 5.2 secs | LR: 0.000698
# INFO:tensorflow:Step 2900 | Loss: 1.3910 | Loss_intent: 1.0995 | Loss_slots: 0.2915 | Spent: 3.0 secs | LR: 0.000684
# INFO:tensorflow:Step 2950 | Loss: 1.5075 | Loss_intent: 1.1187 | Loss_slots: 0.3889 | Spent: 3.0 secs | LR: 0.000670
# INFO:tensorflow:Step 3000 | Loss: 1.6049 | Loss_intent: 1.1096 | Loss_slots: 0.4953 | Spent: 3.2 secs | LR: 0.000656
# INFO:tensorflow:Step 3050 | Loss: 1.5118 | Loss_intent: 1.1672 | Loss_slots: 0.3446 | Spent: 3.1 secs | LR: 0.000642
# INFO:tensorflow:Step 3100 | Loss: 1.3966 | Loss_intent: 1.0999 | Loss_slots: 0.2967 | Spent: 3.0 secs | LR: 0.000628
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.934, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.934, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3150 | Loss: 1.5671 | Loss_intent: 1.1073 | Loss_slots: 0.4598 | Spent: 5.2 secs | LR: 0.000614
# INFO:tensorflow:Step 3200 | Loss: 1.4666 | Loss_intent: 1.1353 | Loss_slots: 0.3313 | Spent: 3.0 secs | LR: 0.000600
# INFO:tensorflow:Step 3250 | Loss: 1.3962 | Loss_intent: 1.1089 | Loss_slots: 0.2873 | Spent: 3.1 secs | LR: 0.000586
# INFO:tensorflow:Step 3300 | Loss: 1.5148 | Loss_intent: 1.0981 | Loss_slots: 0.4167 | Spent: 3.0 secs | LR: 0.000572
# INFO:tensorflow:Step 3350 | Loss: 1.4221 | Loss_intent: 1.1369 | Loss_slots: 0.2851 | Spent: 2.9 secs | LR: 0.000558
# INFO:tensorflow:Step 3400 | Loss: 1.4064 | Loss_intent: 1.1047 | Loss_slots: 0.3017 | Spent: 2.9 secs | LR: 0.000544
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.936, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.936, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3450 | Loss: 1.3575 | Loss_intent: 1.0848 | Loss_slots: 0.2726 | Spent: 5.2 secs | LR: 0.000530
# INFO:tensorflow:Step 3500 | Loss: 1.4673 | Loss_intent: 1.0952 | Loss_slots: 0.3721 | Spent: 3.0 secs | LR: 0.000516
# INFO:tensorflow:Step 3550 | Loss: 1.5647 | Loss_intent: 1.1188 | Loss_slots: 0.4459 | Spent: 2.9 secs | LR: 0.000502
# INFO:tensorflow:Step 3600 | Loss: 1.4888 | Loss_intent: 1.1600 | Loss_slots: 0.3288 | Spent: 2.9 secs | LR: 0.000488
# INFO:tensorflow:Step 3650 | Loss: 1.4061 | Loss_intent: 1.1043 | Loss_slots: 0.3019 | Spent: 3.1 secs | LR: 0.000473
# INFO:tensorflow:Step 3700 | Loss: 1.3907 | Loss_intent: 1.1134 | Loss_slots: 0.2773 | Spent: 3.1 secs | LR: 0.000459
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.937, Intent Acc: 0.970
# INFO:tensorflow:Best Slot F1: 0.937, Intent Acc: 0.970
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 3750 | Loss: 1.4391 | Loss_intent: 1.0913 | Loss_slots: 0.3478 | Spent: 5.4 secs | LR: 0.000445
# INFO:tensorflow:Step 3800 | Loss: 1.4964 | Loss_intent: 1.0930 | Loss_slots: 0.4034 | Spent: 3.2 secs | LR: 0.000431
# INFO:tensorflow:Step 3850 | Loss: 1.3721 | Loss_intent: 1.0848 | Loss_slots: 0.2873 | Spent: 3.3 secs | LR: 0.000417
# INFO:tensorflow:Step 3900 | Loss: 1.3384 | Loss_intent: 1.0965 | Loss_slots: 0.2419 | Spent: 3.1 secs | LR: 0.000403
# INFO:tensorflow:Step 3950 | Loss: 1.4499 | Loss_intent: 1.0893 | Loss_slots: 0.3606 | Spent: 3.1 secs | LR: 0.000389
# INFO:tensorflow:Step 4000 | Loss: 1.4263 | Loss_intent: 1.0836 | Loss_slots: 0.3427 | Spent: 2.9 secs | LR: 0.000375
# INFO:tensorflow:Step 4050 | Loss: 1.4876 | Loss_intent: 1.0986 | Loss_slots: 0.3890 | Spent: 2.9 secs | LR: 0.000361
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.942, Intent Acc: 0.972
# INFO:tensorflow:Best Slot F1: 0.942, Intent Acc: 0.972
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4100 | Loss: 1.3809 | Loss_intent: 1.0864 | Loss_slots: 0.2944 | Spent: 5.2 secs | LR: 0.000347
# INFO:tensorflow:Step 4150 | Loss: 1.4121 | Loss_intent: 1.0918 | Loss_slots: 0.3203 | Spent: 3.2 secs | LR: 0.000333
# INFO:tensorflow:Step 4200 | Loss: 1.3843 | Loss_intent: 1.0962 | Loss_slots: 0.2881 | Spent: 3.1 secs | LR: 0.000319
# INFO:tensorflow:Step 4250 | Loss: 1.3356 | Loss_intent: 1.0867 | Loss_slots: 0.2489 | Spent: 2.9 secs | LR: 0.000305
# INFO:tensorflow:Step 4300 | Loss: 1.4688 | Loss_intent: 1.0883 | Loss_slots: 0.3804 | Spent: 2.9 secs | LR: 0.000291
# INFO:tensorflow:Step 4350 | Loss: 1.4787 | Loss_intent: 1.0868 | Loss_slots: 0.3920 | Spent: 3.0 secs | LR: 0.000277
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.943, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.943, Intent Acc: 0.976
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4400 | Loss: 1.4271 | Loss_intent: 1.0919 | Loss_slots: 0.3352 | Spent: 5.2 secs | LR: 0.000263
# INFO:tensorflow:Step 4450 | Loss: 1.5229 | Loss_intent: 1.0827 | Loss_slots: 0.4403 | Spent: 3.0 secs | LR: 0.000248
# INFO:tensorflow:Step 4500 | Loss: 1.4268 | Loss_intent: 1.0869 | Loss_slots: 0.3399 | Spent: 2.9 secs | LR: 0.000234
# INFO:tensorflow:Step 4550 | Loss: 1.4612 | Loss_intent: 1.0843 | Loss_slots: 0.3769 | Spent: 3.1 secs | LR: 0.000220
# INFO:tensorflow:Step 4600 | Loss: 1.3864 | Loss_intent: 1.0811 | Loss_slots: 0.3052 | Spent: 2.9 secs | LR: 0.000206
# INFO:tensorflow:Step 4650 | Loss: 1.3852 | Loss_intent: 1.0871 | Loss_slots: 0.2980 | Spent: 2.9 secs | LR: 0.000192
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.948, Intent Acc: 0.979
# INFO:tensorflow:Best Slot F1: 0.948, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 4700 | Loss: 1.4245 | Loss_intent: 1.1114 | Loss_slots: 0.3131 | Spent: 5.2 secs | LR: 0.000178
# INFO:tensorflow:Step 4750 | Loss: 1.5337 | Loss_intent: 1.0825 | Loss_slots: 0.4512 | Spent: 2.9 secs | LR: 0.000164
# INFO:tensorflow:Step 4800 | Loss: 1.5266 | Loss_intent: 1.0840 | Loss_slots: 0.4426 | Spent: 2.9 secs | LR: 0.000150
# INFO:tensorflow:Step 4850 | Loss: 1.5024 | Loss_intent: 1.1010 | Loss_slots: 0.4014 | Spent: 3.1 secs | LR: 0.000136
# INFO:tensorflow:Step 4900 | Loss: 1.4543 | Loss_intent: 1.0839 | Loss_slots: 0.3704 | Spent: 2.9 secs | LR: 0.000122
# INFO:tensorflow:Step 4950 | Loss: 1.4712 | Loss_intent: 1.0886 | Loss_slots: 0.3826 | Spent: 3.0 secs | LR: 0.000108
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.947, Intent Acc: 0.973
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.989     0.989     0.989       632
#                             atis_airfare      0.960     1.000     0.980        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      0.941     0.970     0.955        33
#                            atis_aircraft      0.889     0.889     0.889         9
#                         atis_flight_time      0.500     1.000     0.667         1
#                            atis_quantity      0.375     1.000     0.545         3
#                 atis_flight#atis_airfare      0.857     0.500     0.632        12
#                             atis_airport      0.947     1.000     0.973        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      0.800     0.667     0.727         6
#                         atis_ground_fare      1.000     0.857     0.923         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.973     0.979     0.976       888
#                                macro avg      0.642     0.668     0.642       888
#                             weighted avg      0.978     0.979     0.977       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.971     0.993     0.982     716.0
#          B-fromloc.city_name      0.980     0.997     0.989     704.0
#            I-toloc.city_name      0.960     0.992     0.976     265.0
#       B-depart_date.day_name      0.986     0.991     0.988     212.0
#               B-airline_name      0.981     1.000     0.990     101.0
#          I-fromloc.city_name      0.972     0.994     0.983     177.0
#  B-depart_time.period_of_day      0.966     0.877     0.919     130.0
#               I-airline_name      0.985     1.000     0.992      65.0
#     B-depart_date.day_number      0.981     0.945     0.963      55.0
#     B-depart_date.month_name      0.981     0.946     0.964      56.0
#           B-depart_time.time      0.836     0.982     0.903      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.960     1.000     0.980      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.867     1.000     0.929      52.0
#          B-stoploc.city_name      1.000     0.950     0.974      20.0
#                  B-city_name      0.971     0.579     0.725      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.971     0.971     0.971      34.0
#  B-arrive_time.time_relative      0.857     0.968     0.909      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      1.000     0.943     0.971      35.0
#               B-airline_code      1.000     0.882     0.938      34.0
#     I-depart_date.day_number      1.000     1.000     1.000      15.0
#       I-fromloc.airport_name      0.429     1.000     0.600      15.0
#       B-fromloc.airport_name      0.393     0.917     0.550      12.0
#       B-arrive_date.day_name      0.769     0.909     0.833      11.0
#           B-toloc.state_code      0.947     1.000     0.973      18.0
# B-depart_date.today_relative      1.000     0.889     0.941       9.0
#              B-flight_number      0.458     1.000     0.629      11.0
#  B-depart_date.date_relative      0.810     1.000     0.895      17.0
#           B-toloc.state_name      0.962     0.893     0.926      28.0
#            B-fare_basis_code      0.944     1.000     0.971      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.625     0.833     0.714       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.923     0.414     0.571      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.433     0.605      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.625     0.833     0.714       6.0
#     B-arrive_date.day_number      0.625     0.833     0.714       6.0
#          I-stoploc.city_name      1.000     0.800     0.889      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     0.957     0.978      23.0
#     B-depart_time.period_mod      0.800     0.800     0.800       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     0.333     0.500       3.0
#         B-fromloc.state_name      0.895     1.000     0.944      17.0
#               B-airport_name      0.533     0.381     0.444      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.848     0.918      33.0
#                        B-mod      0.500     0.500     0.500       2.0
#               B-airport_code      0.800     0.444     0.571       9.0
#     B-depart_time.start_time      0.667     0.667     0.667       3.0
#       B-depart_time.end_time      1.000     0.667     0.800       3.0
#           B-depart_date.year      1.000     0.667     0.800       3.0
#             I-transport_type      1.000     1.000     1.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      0.667     0.500     0.571       4.0
#       B-arrive_time.end_time      0.800     1.000     0.889       8.0
#       I-arrive_time.end_time      0.800     1.000     0.889       8.0
#       I-depart_time.end_time      1.000     0.333     0.500       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      1.000     1.000     1.000       5.0
#           I-restriction_code      0.600     1.000     0.750       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      0.000     0.000     0.000       2.0
#                 I-flight_mod      0.000     0.000     0.000       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      0.000     0.000     0.000       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      0.000     0.000     0.000       1.0
#  I-depart_time.period_of_day      0.000     0.000     0.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.250     0.400       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      0.000     0.000     0.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.000     0.000     0.000       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.946     0.948     0.947    3657.0
#                    macro avg      0.625     0.604     0.601    3657.0
#                 weighted avg      0.949     0.948     0.943    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.948, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5000 | Loss: 1.3832 | Loss_intent: 1.0863 | Loss_slots: 0.2969 | Spent: 5.3 secs | LR: 0.000103
# INFO:tensorflow:Step 5050 | Loss: 1.4658 | Loss_intent: 1.0887 | Loss_slots: 0.3772 | Spent: 3.2 secs | LR: 0.000110
# INFO:tensorflow:Step 5100 | Loss: 1.3397 | Loss_intent: 1.0829 | Loss_slots: 0.2568 | Spent: 3.1 secs | LR: 0.000117
# INFO:tensorflow:Step 5150 | Loss: 1.4059 | Loss_intent: 1.0849 | Loss_slots: 0.3211 | Spent: 3.1 secs | LR: 0.000124
# INFO:tensorflow:Step 5200 | Loss: 1.4696 | Loss_intent: 1.0887 | Loss_slots: 0.3810 | Spent: 3.0 secs | LR: 0.000131
# INFO:tensorflow:Step 5250 | Loss: 1.4641 | Loss_intent: 1.0817 | Loss_slots: 0.3823 | Spent: 3.3 secs | LR: 0.000138
# INFO:tensorflow:Step 5300 | Loss: 1.4390 | Loss_intent: 1.0826 | Loss_slots: 0.3564 | Spent: 2.9 secs | LR: 0.000145
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.947, Intent Acc: 0.976
# INFO:tensorflow:Best Slot F1: 0.948, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5350 | Loss: 1.4326 | Loss_intent: 1.0863 | Loss_slots: 0.3463 | Spent: 5.4 secs | LR: 0.000152
# INFO:tensorflow:Step 5400 | Loss: 1.4621 | Loss_intent: 1.0853 | Loss_slots: 0.3769 | Spent: 3.2 secs | LR: 0.000159
# INFO:tensorflow:Step 5450 | Loss: 1.4404 | Loss_intent: 1.0813 | Loss_slots: 0.3591 | Spent: 3.0 secs | LR: 0.000166
# INFO:tensorflow:Step 5500 | Loss: 1.3931 | Loss_intent: 1.0837 | Loss_slots: 0.3094 | Spent: 3.0 secs | LR: 0.000173
# INFO:tensorflow:Step 5550 | Loss: 1.2934 | Loss_intent: 1.0969 | Loss_slots: 0.1965 | Spent: 3.0 secs | LR: 0.000180
# INFO:tensorflow:Step 5600 | Loss: 1.4110 | Loss_intent: 1.0825 | Loss_slots: 0.3286 | Spent: 3.2 secs | LR: 0.000187
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.947, Intent Acc: 0.975
# INFO:tensorflow:Best Slot F1: 0.948, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5650 | Loss: 1.4924 | Loss_intent: 1.0829 | Loss_slots: 0.4095 | Spent: 5.4 secs | LR: 0.000194
# INFO:tensorflow:Step 5700 | Loss: 1.4770 | Loss_intent: 1.0867 | Loss_slots: 0.3904 | Spent: 3.0 secs | LR: 0.000202
# INFO:tensorflow:Step 5750 | Loss: 1.4788 | Loss_intent: 1.0817 | Loss_slots: 0.3971 | Spent: 3.0 secs | LR: 0.000209
# INFO:tensorflow:Step 5800 | Loss: 1.4904 | Loss_intent: 1.0812 | Loss_slots: 0.4092 | Spent: 2.9 secs | LR: 0.000216
# INFO:tensorflow:Step 5850 | Loss: 1.4558 | Loss_intent: 1.1047 | Loss_slots: 0.3511 | Spent: 3.0 secs | LR: 0.000223
# INFO:tensorflow:Step 5900 | Loss: 1.3408 | Loss_intent: 1.0885 | Loss_slots: 0.2524 | Spent: 2.9 secs | LR: 0.000230
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.979
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 5950 | Loss: 1.3251 | Loss_intent: 1.1056 | Loss_slots: 0.2195 | Spent: 5.2 secs | LR: 0.000237
# INFO:tensorflow:Step 6000 | Loss: 1.4667 | Loss_intent: 1.0847 | Loss_slots: 0.3820 | Spent: 2.9 secs | LR: 0.000244
# INFO:tensorflow:Step 6050 | Loss: 1.5013 | Loss_intent: 1.0847 | Loss_slots: 0.4166 | Spent: 3.0 secs | LR: 0.000251
# INFO:tensorflow:Step 6100 | Loss: 1.4495 | Loss_intent: 1.1038 | Loss_slots: 0.3457 | Spent: 2.9 secs | LR: 0.000258
# INFO:tensorflow:Step 6150 | Loss: 1.4192 | Loss_intent: 1.0837 | Loss_slots: 0.3355 | Spent: 3.2 secs | LR: 0.000265
# INFO:tensorflow:Step 6200 | Loss: 1.2978 | Loss_intent: 1.1060 | Loss_slots: 0.1919 | Spent: 3.2 secs | LR: 0.000272
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.949, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6250 | Loss: 1.4768 | Loss_intent: 1.0833 | Loss_slots: 0.3935 | Spent: 5.2 secs | LR: 0.000279
# INFO:tensorflow:Step 6300 | Loss: 1.4221 | Loss_intent: 1.0874 | Loss_slots: 0.3346 | Spent: 2.9 secs | LR: 0.000286
# INFO:tensorflow:Step 6350 | Loss: 1.3373 | Loss_intent: 1.0879 | Loss_slots: 0.2494 | Spent: 2.9 secs | LR: 0.000293
# INFO:tensorflow:Step 6400 | Loss: 1.4492 | Loss_intent: 1.0995 | Loss_slots: 0.3497 | Spent: 3.1 secs | LR: 0.000300
# INFO:tensorflow:Step 6450 | Loss: 1.4352 | Loss_intent: 1.0984 | Loss_slots: 0.3367 | Spent: 3.0 secs | LR: 0.000307
# INFO:tensorflow:Step 6500 | Loss: 1.6839 | Loss_intent: 1.2689 | Loss_slots: 0.4150 | Spent: 2.9 secs | LR: 0.000314
# INFO:tensorflow:Step 6550 | Loss: 1.4831 | Loss_intent: 1.1020 | Loss_slots: 0.3810 | Spent: 2.9 secs | LR: 0.000321
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.939, Intent Acc: 0.971
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6600 | Loss: 1.3881 | Loss_intent: 1.0862 | Loss_slots: 0.3019 | Spent: 5.4 secs | LR: 0.000328
# INFO:tensorflow:Step 6650 | Loss: 1.5763 | Loss_intent: 1.1638 | Loss_slots: 0.4125 | Spent: 3.0 secs | LR: 0.000335
# INFO:tensorflow:Step 6700 | Loss: 1.5593 | Loss_intent: 1.0878 | Loss_slots: 0.4716 | Spent: 3.0 secs | LR: 0.000342
# INFO:tensorflow:Step 6750 | Loss: 1.4423 | Loss_intent: 1.0837 | Loss_slots: 0.3586 | Spent: 3.1 secs | LR: 0.000349
# INFO:tensorflow:Step 6800 | Loss: 1.5182 | Loss_intent: 1.1213 | Loss_slots: 0.3969 | Spent: 2.9 secs | LR: 0.000356
# INFO:tensorflow:Step 6850 | Loss: 1.4652 | Loss_intent: 1.0873 | Loss_slots: 0.3779 | Spent: 2.9 secs | LR: 0.000363
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.939, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 6900 | Loss: 1.5120 | Loss_intent: 1.0886 | Loss_slots: 0.4234 | Spent: 5.1 secs | LR: 0.000370
# INFO:tensorflow:Step 6950 | Loss: 1.4675 | Loss_intent: 1.0876 | Loss_slots: 0.3799 | Spent: 3.0 secs | LR: 0.000377
# INFO:tensorflow:Step 7000 | Loss: 1.2802 | Loss_intent: 1.0865 | Loss_slots: 0.1937 | Spent: 2.8 secs | LR: 0.000384
# INFO:tensorflow:Step 7050 | Loss: 1.4807 | Loss_intent: 1.1105 | Loss_slots: 0.3702 | Spent: 3.1 secs | LR: 0.000391
# INFO:tensorflow:Step 7100 | Loss: 1.3781 | Loss_intent: 1.1042 | Loss_slots: 0.2739 | Spent: 2.9 secs | LR: 0.000398
# INFO:tensorflow:Step 7150 | Loss: 1.4770 | Loss_intent: 1.0939 | Loss_slots: 0.3831 | Spent: 2.9 secs | LR: 0.000405
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.946, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.951, Intent Acc: 0.979
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 7200 | Loss: 1.2616 | Loss_intent: 1.0911 | Loss_slots: 0.1705 | Spent: 5.1 secs | LR: 0.000412
# INFO:tensorflow:Step 7250 | Loss: 1.2961 | Loss_intent: 1.0958 | Loss_slots: 0.2004 | Spent: 2.9 secs | LR: 0.000419
# INFO:tensorflow:Step 7300 | Loss: 1.4506 | Loss_intent: 1.0918 | Loss_slots: 0.3588 | Spent: 2.9 secs | LR: 0.000427
# INFO:tensorflow:Step 7350 | Loss: 1.5120 | Loss_intent: 1.1218 | Loss_slots: 0.3902 | Spent: 2.9 secs | LR: 0.000434
# INFO:tensorflow:Step 7400 | Loss: 1.4076 | Loss_intent: 1.0937 | Loss_slots: 0.3139 | Spent: 3.0 secs | LR: 0.000441
# INFO:tensorflow:Step 7450 | Loss: 1.4319 | Loss_intent: 1.0917 | Loss_slots: 0.3402 | Spent: 3.0 secs | LR: 0.000448
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.934, Intent Acc: 0.969
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.975     0.991     0.983       632
#                             atis_airfare      0.960     1.000     0.980        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      1.000     1.000     1.000        38
#                        atis_abbreviation      1.000     1.000     1.000        33
#                            atis_aircraft      1.000     0.889     0.941         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.375     1.000     0.545         3
#                 atis_flight#atis_airfare      0.667     0.167     0.267        12
#                             atis_airport      0.941     0.889     0.914        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      0.667     0.667     0.667         6
#                         atis_ground_fare      1.000     0.857     0.923         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
# ...
# INFO:tensorflow:Step 18300 | Loss: 1.4131 | Loss_intent: 1.0844 | Loss_slots: 0.3287 | Spent: 2.9 secs | LR: 0.000157
# INFO:tensorflow:Step 18350 | Loss: 1.3250 | Loss_intent: 1.0816 | Loss_slots: 0.2434 | Spent: 2.9 secs | LR: 0.000155
# INFO:tensorflow:Step 18400 | Loss: 1.2951 | Loss_intent: 1.0805 | Loss_slots: 0.2146 | Spent: 2.8 secs | LR: 0.000153
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.955, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18450 | Loss: 1.3778 | Loss_intent: 1.0805 | Loss_slots: 0.2974 | Spent: 5.1 secs | LR: 0.000151
# INFO:tensorflow:Step 18500 | Loss: 1.4512 | Loss_intent: 1.0849 | Loss_slots: 0.3663 | Spent: 3.1 secs | LR: 0.000150
# INFO:tensorflow:Step 18550 | Loss: 1.3711 | Loss_intent: 1.0816 | Loss_slots: 0.2896 | Spent: 3.0 secs | LR: 0.000148
# INFO:tensorflow:Step 18600 | Loss: 1.3610 | Loss_intent: 1.0809 | Loss_slots: 0.2801 | Spent: 3.0 secs | LR: 0.000146
# INFO:tensorflow:Step 18650 | Loss: 1.4260 | Loss_intent: 1.0801 | Loss_slots: 0.3459 | Spent: 3.2 secs | LR: 0.000144
# INFO:tensorflow:Step 18700 | Loss: 1.3873 | Loss_intent: 1.0808 | Loss_slots: 0.3066 | Spent: 2.9 secs | LR: 0.000143
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.953, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 18750 | Loss: 1.3867 | Loss_intent: 1.0809 | Loss_slots: 0.3058 | Spent: 5.1 secs | LR: 0.000141
# INFO:tensorflow:Step 18800 | Loss: 1.4969 | Loss_intent: 1.0802 | Loss_slots: 0.4167 | Spent: 3.2 secs | LR: 0.000139
# INFO:tensorflow:Step 18850 | Loss: 1.4525 | Loss_intent: 1.0812 | Loss_slots: 0.3712 | Spent: 3.0 secs | LR: 0.000137
# INFO:tensorflow:Step 18900 | Loss: 1.4074 | Loss_intent: 1.0803 | Loss_slots: 0.3271 | Spent: 2.9 secs | LR: 0.000136
# INFO:tensorflow:Step 18950 | Loss: 1.4222 | Loss_intent: 1.0811 | Loss_slots: 0.3411 | Spent: 2.9 secs | LR: 0.000134
# INFO:tensorflow:Step 19000 | Loss: 1.4383 | Loss_intent: 1.0831 | Loss_slots: 0.3553 | Spent: 2.9 secs | LR: 0.000132
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19050 | Loss: 1.4113 | Loss_intent: 1.0821 | Loss_slots: 0.3291 | Spent: 5.1 secs | LR: 0.000130
# INFO:tensorflow:Step 19100 | Loss: 1.3745 | Loss_intent: 1.0806 | Loss_slots: 0.2940 | Spent: 2.9 secs | LR: 0.000129
# INFO:tensorflow:Step 19150 | Loss: 1.4496 | Loss_intent: 1.0806 | Loss_slots: 0.3690 | Spent: 3.0 secs | LR: 0.000127
# INFO:tensorflow:Step 19200 | Loss: 1.4081 | Loss_intent: 1.0811 | Loss_slots: 0.3270 | Spent: 2.8 secs | LR: 0.000125
# INFO:tensorflow:Step 19250 | Loss: 1.3397 | Loss_intent: 1.0810 | Loss_slots: 0.2586 | Spent: 2.9 secs | LR: 0.000123
# INFO:tensorflow:Step 19300 | Loss: 1.4319 | Loss_intent: 1.0811 | Loss_slots: 0.3507 | Spent: 3.0 secs | LR: 0.000122
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.954, Intent Acc: 0.974
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19350 | Loss: 1.3599 | Loss_intent: 1.0822 | Loss_slots: 0.2777 | Spent: 5.3 secs | LR: 0.000120
# INFO:tensorflow:Step 19400 | Loss: 1.4187 | Loss_intent: 1.0838 | Loss_slots: 0.3350 | Spent: 3.1 secs | LR: 0.000118
# INFO:tensorflow:Step 19450 | Loss: 1.4901 | Loss_intent: 1.0831 | Loss_slots: 0.4071 | Spent: 2.9 secs | LR: 0.000116
# INFO:tensorflow:Step 19500 | Loss: 1.6075 | Loss_intent: 1.0805 | Loss_slots: 0.5270 | Spent: 2.9 secs | LR: 0.000114
# INFO:tensorflow:Step 19550 | Loss: 1.3524 | Loss_intent: 1.0821 | Loss_slots: 0.2703 | Spent: 3.1 secs | LR: 0.000113
# INFO:tensorflow:Step 19600 | Loss: 1.4670 | Loss_intent: 1.0814 | Loss_slots: 0.3856 | Spent: 2.9 secs | LR: 0.000111
# INFO:tensorflow:Step 19650 | Loss: 1.3410 | Loss_intent: 1.0817 | Loss_slots: 0.2593 | Spent: 3.0 secs | LR: 0.000109
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.952, Intent Acc: 0.973
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.973
# Reading ../data/atis.train.w-intent.iob
# INFO:tensorflow:Step 19700 | Loss: 1.4683 | Loss_intent: 1.0804 | Loss_slots: 0.3879 | Spent: 5.2 secs | LR: 0.000107
# INFO:tensorflow:Step 19750 | Loss: 1.3564 | Loss_intent: 1.0812 | Loss_slots: 0.2752 | Spent: 3.0 secs | LR: 0.000106
# INFO:tensorflow:Step 19800 | Loss: 1.3808 | Loss_intent: 1.0800 | Loss_slots: 0.3008 | Spent: 3.0 secs | LR: 0.000104
# INFO:tensorflow:Step 19850 | Loss: 1.2688 | Loss_intent: 1.0816 | Loss_slots: 0.1873 | Spent: 2.9 secs | LR: 0.000102
# INFO:tensorflow:Step 19900 | Loss: 1.2986 | Loss_intent: 1.0826 | Loss_slots: 0.2160 | Spent: 3.1 secs | LR: 0.000100
# INFO:tensorflow:Step 19950 | Loss: 1.5257 | Loss_intent: 1.0825 | Loss_slots: 0.4432 | Spent: 3.0 secs | LR: 0.000101
# Reading ../data/atis.test.w-intent.iob
# INFO:tensorflow:Slot F1: 0.951, Intent Acc: 0.974
# INFO:tensorflow:
#                                           precision    recall  f1-score   support
#
#                              atis_flight      0.984     0.991     0.987       632
#                             atis_airfare      0.959     0.979     0.969        48
#                      atis_ground_service      1.000     1.000     1.000        36
#                             atis_airline      0.974     1.000     0.987        38
#                        atis_abbreviation      0.941     0.970     0.955        33
#                            atis_aircraft      1.000     1.000     1.000         9
#                         atis_flight_time      1.000     1.000     1.000         1
#                            atis_quantity      0.429     1.000     0.600         3
#                 atis_flight#atis_airfare      0.833     0.417     0.556        12
#                             atis_airport      0.947     1.000     0.973        18
#                            atis_distance      1.000     1.000     1.000        10
#                                atis_city      1.000     0.667     0.800         6
#                         atis_ground_fare      1.000     1.000     1.000         7
#                            atis_capacity      1.000     1.000     1.000        21
#                           atis_flight_no      0.889     1.000     0.941         8
#                                atis_meal      1.000     0.833     0.909         6
#                         atis_restriction      0.000     0.000     0.000         0
#              atis_airline#atis_flight_no      0.000     0.000     0.000         0
#     atis_ground_service#atis_ground_fare      0.000     0.000     0.000         0
#            atis_airfare#atis_flight_time      0.000     0.000     0.000         0
#                            atis_cheapest      0.000     0.000     0.000         0
# atis_aircraft#atis_flight#atis_flight_no      0.000     0.000     0.000         0
#
#                                micro avg      0.974     0.980     0.977       888
#                                macro avg      0.680     0.675     0.667       888
#                             weighted avg      0.977     0.980     0.977       888
#
# INFO:tensorflow:
#                               precision    recall  f1-score   support
#
#                            O      0.000     0.000     0.000       0.0
#            B-toloc.city_name      0.974     0.993     0.983     716.0
#          B-fromloc.city_name      0.982     0.999     0.990     704.0
#            I-toloc.city_name      0.970     0.985     0.978     265.0
#       B-depart_date.day_name      0.991     0.991     0.991     212.0
#               B-airline_name      1.000     1.000     1.000     101.0
#          I-fromloc.city_name      0.941     0.994     0.967     177.0
#  B-depart_time.period_of_day      1.000     0.908     0.952     130.0
#               I-airline_name      1.000     1.000     1.000      65.0
#     B-depart_date.day_number      0.981     0.964     0.972      55.0
#     B-depart_date.month_name      0.982     0.964     0.973      56.0
#           B-depart_time.time      0.836     0.982     0.903      57.0
#                 B-round_trip      1.000     0.986     0.993      73.0
#              B-cost_relative      1.000     0.973     0.986      37.0
#                 I-round_trip      1.000     1.000     1.000      71.0
#                 B-flight_mod      0.828     1.000     0.906      24.0
#  B-depart_time.time_relative      0.969     0.969     0.969      65.0
#           I-depart_time.time      0.927     0.981     0.953      52.0
#          B-stoploc.city_name      1.000     0.950     0.974      20.0
#                  B-city_name      0.825     0.579     0.680      57.0
#                 B-class_type      0.960     1.000     0.980      24.0
#           B-arrive_time.time      0.971     0.971     0.971      34.0
#  B-arrive_time.time_relative      0.853     0.935     0.892      31.0
#                 I-class_type      1.000     1.000     1.000      17.0
#                B-flight_stop      1.000     1.000     1.000      21.0
#           I-arrive_time.time      1.000     0.971     0.986      35.0
#               B-airline_code      1.000     0.912     0.954      34.0
#     I-depart_date.day_number      1.000     0.933     0.966      15.0
#       I-fromloc.airport_name      0.429     1.000     0.600      15.0
#       B-fromloc.airport_name      0.462     1.000     0.632      12.0
#       B-arrive_date.day_name      0.786     1.000     0.880      11.0
#           B-toloc.state_code      0.947     1.000     0.973      18.0
# B-depart_date.today_relative      1.000     1.000     1.000       9.0
#              B-flight_number      0.458     1.000     0.629      11.0
#  B-depart_date.date_relative      0.895     1.000     0.944      17.0
#           B-toloc.state_name      0.926     0.893     0.909      28.0
#            B-fare_basis_code      0.917     0.647     0.759      17.0
#                B-flight_time      1.000     1.000     1.000       1.0
#                         B-or      1.000     1.000     1.000       3.0
#  B-arrive_time.period_of_day      0.750     1.000     0.857       6.0
#           B-meal_description      1.000     0.900     0.947      10.0
#              I-cost_relative      1.000     0.667     0.800       3.0
#               I-airport_name      0.917     0.379     0.537      29.0
#                B-fare_amount      1.000     1.000     1.000       2.0
#                I-fare_amount      1.000     1.000     1.000       2.0
#                  I-city_name      1.000     0.400     0.571      30.0
#         I-toloc.airport_name      1.000     1.000     1.000       3.0
#             B-transport_type      1.000     1.000     1.000      10.0
#     B-arrive_date.month_name      0.714     0.833     0.769       6.0
#     B-arrive_date.day_number      0.714     0.833     0.769       6.0
#          I-stoploc.city_name      1.000     0.900     0.947      10.0
#                       B-meal      1.000     1.000     1.000      16.0
#         B-fromloc.state_code      1.000     0.957     0.978      23.0
#     B-depart_time.period_mod      1.000     1.000     1.000       5.0
#                    B-connect      1.000     1.000     1.000       6.0
#                B-flight_days      1.000     1.000     1.000      10.0
#         B-toloc.airport_name      1.000     1.000     1.000       3.0
#         B-fromloc.state_name      1.000     1.000     1.000      17.0
#               B-airport_name      0.818     0.429     0.562      21.0
#                    B-economy      1.000     1.000     1.000       6.0
#                I-flight_time      1.000     1.000     1.000       1.0
#              B-aircraft_code      1.000     0.818     0.900      33.0
#                        B-mod      1.000     0.500     0.667       2.0
#               B-airport_code      0.500     0.111     0.182       9.0
#     B-depart_time.start_time      0.500     0.667     0.571       3.0
#       B-depart_time.end_time      0.667     0.667     0.667       3.0
#           B-depart_date.year      0.750     1.000     0.857       3.0
#             I-transport_type      1.000     1.000     1.000       1.0
#           B-restriction_code      1.000     1.000     1.000       4.0
#     B-arrive_time.start_time      0.889     1.000     0.941       8.0
#         B-toloc.airport_code      1.000     0.750     0.857       4.0
#       B-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-arrive_time.end_time      0.889     1.000     0.941       8.0
#       I-depart_time.end_time      0.667     0.667     0.667       3.0
#                I-flight_stop      0.000     0.000     0.000       0.0
#       B-fromloc.airport_code      1.000     1.000     1.000       5.0
#           I-restriction_code      0.214     1.000     0.353       3.0
#     I-depart_time.start_time      1.000     1.000     1.000       1.0
#           I-toloc.state_name      1.000     1.000     1.000       1.0
# I-depart_date.today_relative      0.000     0.000     0.000       0.0
#  B-arrive_date.date_relative      1.000     0.500     0.667       2.0
#                 I-flight_mod      1.000     0.167     0.286       6.0
#                    I-economy      0.000     0.000     0.000       0.0
#  B-return_date.date_relative      1.000     0.333     0.500       3.0
#         I-fromloc.state_name      1.000     1.000     1.000       1.0
#                 B-state_code      1.000     1.000     1.000       1.0
#     I-arrive_time.start_time      1.000     1.000     1.000       1.0
#     I-arrive_date.day_number      0.000     0.000     0.000       0.0
#                  B-meal_code      1.000     1.000     1.000       1.0
#  I-depart_time.period_of_day      1.000     1.000     1.000       1.0
#                   B-day_name      1.000     0.500     0.667       2.0
#              B-period_of_day      1.000     0.750     0.857       4.0
#         B-stoploc.state_code      0.000     0.000     0.000       0.0
#     B-return_date.month_name      0.000     0.000     0.000       0.0
#     B-return_date.day_number      0.000     0.000     0.000       0.0
#     B-arrive_time.period_mod      0.000     0.000     0.000       0.0
#                  I-meal_code      0.000     0.000     0.000       0.0
#         B-toloc.country_name      1.000     1.000     1.000       1.0
#                  B-days_code      1.000     1.000     1.000       1.0
#  I-arrive_time.period_of_day      0.000     0.000     0.000       0.0
#             I-today_relative      0.000     0.000     0.000       0.0
#  B-return_time.period_of_day      0.000     0.000     0.000       0.0
#                       B-time      0.000     0.000     0.000       0.0
#            I-fare_basis_code      0.000     0.000     0.000       0.0
#  I-arrive_time.time_relative      0.000     0.000     0.000       4.0
#  I-depart_time.time_relative      0.000     0.000     0.000       1.0
#             B-today_relative      0.000     0.000     0.000       0.0
#                 B-state_name      0.000     0.000     0.000       9.0
# B-arrive_date.today_relative      0.000     0.000     0.000       0.0
#     B-return_time.period_mod      0.000     0.000     0.000       0.0
#                 B-month_name      0.000     0.000     0.000       0.0
#                 B-day_number      0.000     0.000     0.000       0.0
#  I-return_date.date_relative      0.750     1.000     0.857       3.0
# I-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-stoploc.airport_name      0.000     0.000     0.000       0.0
#              B-time_relative      0.000     0.000     0.000       0.0
#                       I-time      0.000     0.000     0.000       0.0
#     I-return_date.day_number      0.000     0.000     0.000       0.0
#           I-meal_description      0.000     0.000     0.000       0.0
# B-return_date.today_relative      0.000     0.000     0.000       0.0
#       B-return_date.day_name      0.000     0.000     0.000       2.0
#
#                    micro avg      0.950     0.952     0.951    3657.0
#                    macro avg      0.681     0.663     0.656    3657.0
#                 weighted avg      0.956     0.952     0.948    3657.0
#
# INFO:tensorflow:Best Slot F1: 0.956, Intent Acc: 0.973
